# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.metrics import PredictionErrorDisplay
from sklearn.model_selection import cross_val_predict

# %%
ames_lasso = pd.read_csv('ames.csv', index_col=0)
ames_lasso.head(10)
ames_lasso.columns
# Out:
# Index(['PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'TotalBath', 'TotalSF', 'HQSF', 'yrsbtwn'],
#       dtype='object')

# %%
ames_lasso['BedxBath'] = ames_lasso['TotalBath'] * ames_lasso['BedroomAbvGr']
ames_lasso['RoomsxBath'] = ames_lasso['TotalBath'] * ames_lasso['TotRmsAbvGrd']
ames_lasso['FireplaceYN'] = ames_lasso['Fireplaces'].apply(lambda x: 1 if x != 0 else 0)
ames_lasso['MSSubClass'] = ames_lasso['MSSubClass'].astype(str)
ames_lasso['TotalPorchSF'] = ames_lasso[['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch',\
                                    '3SsnPorch', 'ScreenPorch']].sum(axis=1)

# %%
for col in ['TotalBath', 'BedroomAbvGr', 'BedxBath', 'TotRmsAbvGrd', 'RoomsxBath']:    
    y = ames_lasso[['SalePrice']]
    X = ames_lasso[[col]]

    model = LinearRegression()

    print(f"{col}: {cross_val_score(model, X, y, cv=5)}")
#Hmm bedxbath isn't as good as I was hoping- seems to float in the .2s when just totalbath has us in the high .3's
#rooms times bath is better though!
# Out:
# TotalBath: [0.38861611 0.40395472 0.4240881  0.35434749 0.45076023]
# BedroomAbvGr: [ 0.00912911  0.02580596  0.02918927 -0.00509804  0.00617873]
# BedxBath: [0.22343336 0.22041497 0.27835996 0.20504526 0.28500869]
# TotRmsAbvGrd: [0.23881318 0.26073385 0.25681296 0.19182688 0.18911569]
# RoomsxBath: [0.44445362 0.47467311 0.47514827 0.39561659 0.48294281]

# %%
ames_lasso.columns
# Out:
# Index(['PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'TotalBath', 'TotalSF', 'HQSF', 'yrsbtwn', 'BedxBath',
#        'RoomsxBath', 'FireplaceYN', 'TotalPorchSF'],
#       dtype='object')

# %%
ames_lasso['TotalPorchSF']
# Out:
# 1      166
# 2      105
# 3      282
# 4      279
# 5       45
#       ...
# 759    138
# 760      0
# 761      0
# 762    289
# 763    263
# Name: TotalPorchSF, Length: 2580, dtype: int64

# %%
#All columns prepared to encode differently
all_cols = []

nominal_cols = ['Alley','BldgType','CentralAir','Condition1','Condition2','Electrical','Exterior1st','Exterior2nd','Fence',
           'Foundation','GarageType','Heating','HouseStyle','LandContour','LotConfig','MSSubClass','MSZoning',
           'MasVnrType','MiscFeature','MoSold','Neighborhood','PavedDrive','RoofMatl','RoofStyle','SaleCondition',
           'SaleType','Street','YrSold'] #FireplaceYN

ordinal_cols = ['LotShape','Utilities','LandSlope','ExterQual','ExterCond','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
 'BsmtFinType2','HeatingQC','KitchenQual','Functional','FireplaceQu','GarageFinish','GarageQual','GarageCond','PoolQC']

numerical_cols = ['GrLivArea','LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MasVnrArea',
             'BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','BsmtFullBath',
             'BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces', 'Age'
             'GarageYrBlt','GarageCars','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch',
             'ScreenPorch','PoolArea','MiscVal', 'TotalSF', 'TotalBath', 'HQSF', 'yrsbtwn', 'BedxBath', 
             'GarageYrBlt','RoomsxBath', 'TotalPorchSF']

all_cols.extend(nominal_cols)
all_cols.extend(ordinal_cols)
all_cols.extend(numerical_cols)

for col in ames_lasso.columns:
    if col not in all_cols:
        print(col)
# Out:
# PID
# SalePrice
# FireplaceYN

# %%
#Hybrid encoding- encode ordinal features/dummify nominal features. Don't drop columns for dummifying nominal feats
#because lasso does the dropping for you, reducing coefficients of some variables all the way to 0. Effectively performs
#feature selection!

ordinal_mappings = {
    'BsmtCond': {'No Bsmt': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5},
    'BsmtExposure': {'No Bsmt': 0, 'No': 1, 'Mn': 2, 'Av': 3, 'Gd': 4},
    'BsmtFinType1': {'No Bsmt': 0, 'Unf': 1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ': 5, 'GLQ': 6},
    'BsmtFinType2': {'No Bsmt': 0, 'Unf': 1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ': 5, 'GLQ': 6}, 
    'BsmtQual': {'No Bsmt': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5}, 
    'ExterCond': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5}, 
    'ExterQual': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5}, 
    'FireplaceQu': {'No Fireplace': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5}, 
    'Functional': {'Sal':1, 'Maj2':2, 'Maj1':3 , 'Mod':4 ,'Min2':5 , 'Min1':6 ,'Typ':7}, 
    'GarageCond': {'No Garage': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5}, 
    'GarageFinish': {'No Garage': 0, 'Unf':1, 'RFn':2, 'Fin':3}, 
    'GarageQual': {'No Garage': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5 }, 
    'HeatingQC': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5 }, 
    'KitchenQual': {'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5 }, 
    'LandSlope': {'Gtl':1, 'Mod':2, 'Sev':3}, 
    'LotShape': {'IR3':1, 'IR2':2, 'IR1':3, 'Reg':4},
    'PavedDrive': {'N':1, 'P':2, 'Y':3}, 
    'PoolQC': {'No Pool': 0, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5},
    'Utilities': {'ELO': 0, 'NoSeWa': 1, 'NoSewr': 2, 'AllPub': 3}
    
}

# Map ordinal variables
for col_key, mapping_vals in ordinal_mappings.items():
    if col_key in ames_lasso.columns:
        ames_lasso[col_key] = ames_lasso[col_key].map(mapping_vals)

ames_lasso_encoded = ames_lasso.copy()

ames_lasso_encoded_nodrop = pd.get_dummies(ames_lasso_encoded, columns=nominal_cols, drop_first=False)

# %%
ames_lasso_encoded_nodrop
# Out:
#            PID  GrLivArea  SalePrice  LotFrontage  LotArea  LotShape  \
# 1    909176150        856     126000    58.769231     7890         4
# 2    905476230       1049     139500    42.000000     4235         4
# 3    911128020       1001     124900    60.000000     6060         4
# 4    535377150       1039     114000    80.000000     8146         4
# 5    534177230       1665     227000    70.000000     8400         4
# ..         ...        ...        ...          ...      ...       ...
# 759  903205040        952     121000    55.945652     8854         4
# 760  905402060       1733     139600    65.490066    13680         3
# 761  909275030       2002     145000    82.000000     6270         4
# 762  907192040       1842     217500    69.978947     8826         4
# 763  906223180       1911     215000    80.000000     9554         3
#
#      Utilities  LandSlope  OverallQual  OverallCond  ...  SaleType_Oth  \
# 1            3          1            6            6  ...         False
# 2            3          1            5            5  ...         False
# 3            3          1            5            9  ...         False
# 4            3          1            4            8  ...         False
# 5            3          1            8            6  ...         False
# ..         ...        ...          ...          ...  ...           ...
# 759          3          1            6            6  ...         False
# 760          3          1            3            5  ...         False
# 761          3          1            5            6  ...         False
# 762          3          1            7            5  ...         False
# 763          3          1            8            5  ...         False
#
#      SaleType_VWD  SaleType_WD   Street_Grvl  Street_Pave  YrSold_2006  \
# 1           False          True        False         True        False
# 2           False          True        False         True        False
# 3           False          True        False         True        False
# 4           False          True        False         True        False
# 5           False          True        False         True        False
# ..            ...           ...          ...          ...          ...
# 759         False          True        False         True        False
# 760         False          True        False         True        False
# 761         False          True        False         True        False
# 762         False          True        False         True        False
# 763         False          True        False         True         True
#
#      YrSold_2007  YrSold_2008  YrSold_2009  YrSold_2010
# 1          False        False        False         True
# 2          False        False         True        False
# 3           True        False        False        False
# 4          False        False         True        False
# 5          False        False         True        False
# ..           ...          ...          ...          ...
# 759        False        False         True        False
# 760        False        False         True        False
# 761         True        False        False        False
# 762         True        False        False        False
# 763        False        False        False        False
#
# [2580 rows x 275 columns]

# %% [markdown]
# ## Scaling/Leakage
# Need to be particular here about scaling to avoid data leakage and to avoid scaling dummified variables.

# %%
#Split columns into ones to scale and dummified (to not scale)
col_list = ames_lasso_encoded_nodrop.columns.tolist()
dummified_cols = []
cols_to_scale = []
for col_name in col_list:
    if "_" in col_name:
        dummified_cols.append(col_name)
    else:
        cols_to_scale.append(col_name)

# %%
cols_to_scale
cols_to_scale.remove('PID')
cols_to_scale.remove('SalePrice')

# %%
#Want to avoid scaling dummified variables, but would also like to include scaling in a pipeline.

class SubsetScaler(BaseEstimator, TransformerMixin):
    def __init__(self, cols_to_scale):
        self.cols_to_scale = cols_to_scale
        self.scaler = StandardScaler()
    
    def fit(self, X, y=None):
        self.scaler.fit(X[self.cols_to_scale], y)
        return self
    
    def transform(self, X):
        X_scaled = X.copy()
        X_scaled[self.cols_to_scale] = self.scaler.transform(X[self.cols_to_scale])
        return X_scaled

pipeline = Pipeline([
    ('scaler', SubsetScaler(cols_to_scale)), #SubsetScaler
    ('model', Lasso(max_iter = 10000))
])

# %%
#Feature Selection using Lasso- train_test split
X = ames_lasso_encoded_nodrop.drop(columns = ['PID', 'SalePrice'], axis = 1)
y = ames_lasso_encoded_nodrop['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0)

# %% [markdown]
# Run a series of gridsearches with the created pipeline. We need to tune alpha/lambda, the penalization term in the Lasso. Start with a very wide range and then gradually zoom in.

# %%
log_scale_search = GridSearchCV(pipeline,
                     {'model__alpha': np.logspace(-3, 5, 8)},
                     cv = 5,
                     scoring = 'r2',
                    return_train_score=True,
                     verbose = 1)

# %%
log_scale_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.639e+11, tolerance: 9.542e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.094e+11, tolerance: 8.683e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.794e+11, tolerance: 9.092e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.155e+11, tolerance: 9.376e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.604e+11, tolerance: 8.320e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.780e+11, tolerance: 9.542e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.558e+11, tolerance: 8.683e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.862e+11, tolerance: 9.092e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.823e+11, tolerance: 9.376e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.281e+11, tolerance: 8.320e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.609e+10, tolerance: 9.542e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.284e+10, tolerance: 8.683e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.064e+10, tolerance: 9.092e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.433e+10, tolerance: 9.376e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.483e+10, tolerance: 8.320e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.671e+09, tolerance: 9.542e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.337e+09, tolerance: 8.683e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.022e+09, tolerance: 9.092e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.586e+09, tolerance: 9.376e+08
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.555e+09, tolerance: 8.320e+08
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler',
#                                         SubsetScaler(cols_to_scale=['GrLivArea',
#                                                                     'LotFrontage',
#                                                                     'LotArea',
#                                                                     'LotShape',
#                                                                     'Utilities',
#                                                                     'LandSlope',
#                                                                     'OverallQual',
#                                                                     'OverallCond',
#                                                                     'YearBuilt',
#                                                                     'YearRemodAdd',
#                                                                     'MasVnrArea',
#                                                                     'ExterQual',
#                                                                     'ExterCond',
#                                                                     'BsmtQual',
#                                                                     'BsmtCond',
#                                                                     'BsmtExposure',
#                                                                     'BsmtFinType1',
#                                                                     'BsmtFinSF1',
#                                                                     'BsmtFinType2',
#                                                                     'BsmtFinSF2',
#                                                                     'BsmtUnfSF',
#                                                                     'TotalBsmtSF',
#                                                                     'HeatingQC',
#                                                                     '1stFlrSF',
#                                                                     '2ndFlrSF',
#                                                                     'LowQualFinSF',
#                                                                     'BsmtFullBath',
#                                                                     'BsmtHalfBath',
#                                                                     'FullBath',
#                                                                     'HalfBath', ...])),
#                                        ('model', Lasso(max_iter=10000))]),
#              param_grid={'model__alpha': array([1.00000000e-03, 1.38949549e-02, 1.93069773e-01, 2.68269580e+00,
#        3.72759372e+01, 5.17947468e+02, 7.19685673e+03, 1.00000000e+05])},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
def alpha_tune_plot(mygridsearch):
    
    results = mygridsearch.cv_results_
    train_score = results['mean_train_score']
    test_score = results['mean_test_score']
    alphas = results['param_model__alpha'].data.astype(float)

    best_alpha = mygridsearch.best_params_['model__alpha']

    plt.figure(figsize=(10, 6))
    plt.plot(alphas, train_score, label = 'Train', marker='o')
    plt.plot(alphas, test_score, label = 'Test', marker = 'o')
    plt.title('Tuning Alpha: Alpha vs. Lasso R$^2$ with 5-Fold Cross-Validation')
    plt.xlabel('Alpha')
    plt.ylabel('Average R2 Score')
    plt.grid(True)

    plt.axvline(x=best_alpha, color='r', linestyle='--', label = f'Best Alpha\n{round(best_alpha, 2)}')
    plt.legend()
    plt.show()
    
alpha_tune_plot(log_scale_search)

# %%
thousand_search = GridSearchCV(pipeline,
                     {'model__alpha': np.linspace(0, 1000, 20)},
                     cv = 5,
                     scoring = 'r2',
                    return_train_score=True,
                     verbose = 1)

# %%
thousand_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.733e+11, tolerance: 9.542e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.234e+11, tolerance: 8.683e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.888e+11, tolerance: 9.092e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.264e+11, tolerance: 9.376e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.721e+11, tolerance: 8.320e+08 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler',
#                                         SubsetScaler(cols_to_scale=['GrLivArea',
#                                                                     'LotFrontage',
#                                                                     'LotArea',
#                                                                     'LotShape',
#                                                                     'Utilities',
#                                                                     'LandSlope',
#                                                                     'OverallQual',
#                                                                     'OverallCond',
#                                                                     'YearBuilt',
#                                                                     'YearRemodAdd',
#                                                                     'MasVnrArea',
#                                                                     'ExterQual',
#                                                                     'ExterCond',
#                                                                     'BsmtQual',
#                                                                     'BsmtCond',
#                                                                     'BsmtExposure',
#                                                                     'BsmtFinType1',
#                                                                     'BsmtFinSF1',
#                                                                     'BsmtFinType2',
#                                                                     'BsmtFinSF2',
#                                                                     'BsmtUnfSF',...
#                                        ('model', Lasso(max_iter=10000))]),
#              param_grid={'model__alpha': array([   0.        ,   52.63157895,  105.26315789,  157.89473684,
#         210.52631579,  263.15789474,  315.78947368,  368.42105263,
#         421.05263158,  473.68421053,  526.31578947,  578.94736842,
#         631.57894737,  684.21052632,  736.84210526,  789.47368421,
#         842.10526316,  894.73684211,  947.36842105, 1000.        ])},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
alpha_tune_plot(thousand_search)
#Where the train curve is at its highest while also being closest to test is an optimal value for alpha.
#In this way we can shoot for best performance possible while avoiding overfitting.

# %%
forty_search = GridSearchCV(pipeline,
                     {'model__alpha': np.linspace(180, 220, 20)},
                     cv = 5,
                     scoring = 'r2',
                      return_train_score=True,
                     verbose = 1)
forty_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler',
#                                         SubsetScaler(cols_to_scale=['GrLivArea',
#                                                                     'LotFrontage',
#                                                                     'LotArea',
#                                                                     'LotShape',
#                                                                     'Utilities',
#                                                                     'LandSlope',
#                                                                     'OverallQual',
#                                                                     'OverallCond',
#                                                                     'YearBuilt',
#                                                                     'YearRemodAdd',
#                                                                     'MasVnrArea',
#                                                                     'ExterQual',
#                                                                     'ExterCond',
#                                                                     'BsmtQual',
#                                                                     'BsmtCond',
#                                                                     'BsmtExposure',
#                                                                     'BsmtFinType1',
#                                                                     'BsmtFinSF1',
#                                                                     'BsmtFinType2',
#                                                                     'BsmtFinSF2',
#                                                                     'BsmtUnfSF',...
#                                        ('model', Lasso(max_iter=10000))]),
#              param_grid={'model__alpha': array([180.        , 182.10526316, 184.21052632, 186.31578947,
#        188.42105263, 190.52631579, 192.63157895, 194.73684211,
#        196.84210526, 198.94736842, 201.05263158, 203.15789474,
#        205.26315789, 207.36842105, 209.47368421, 211.57894737,
#        213.68421053, 215.78947368, 217.89473684, 220.        ])},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
alpha_tune_plot(forty_search)

# %%
four_search = GridSearchCV(pipeline,
                     {'model__alpha': np.linspace(200, 205, 4)},
                     cv = 5,
                     scoring = 'r2',
                      return_train_score=True,
                     verbose = 1)
four_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler',
#                                         SubsetScaler(cols_to_scale=['GrLivArea',
#                                                                     'LotFrontage',
#                                                                     'LotArea',
#                                                                     'LotShape',
#                                                                     'Utilities',
#                                                                     'LandSlope',
#                                                                     'OverallQual',
#                                                                     'OverallCond',
#                                                                     'YearBuilt',
#                                                                     'YearRemodAdd',
#                                                                     'MasVnrArea',
#                                                                     'ExterQual',
#                                                                     'ExterCond',
#                                                                     'BsmtQual',
#                                                                     'BsmtCond',
#                                                                     'BsmtExposure',
#                                                                     'BsmtFinType1',
#                                                                     'BsmtFinSF1',
#                                                                     'BsmtFinType2',
#                                                                     'BsmtFinSF2',
#                                                                     'BsmtUnfSF',
#                                                                     'TotalBsmtSF',
#                                                                     'HeatingQC',
#                                                                     '1stFlrSF',
#                                                                     '2ndFlrSF',
#                                                                     'LowQualFinSF',
#                                                                     'BsmtFullBath',
#                                                                     'BsmtHalfBath',
#                                                                     'FullBath',
#                                                                     'HalfBath', ...])),
#                                        ('model', Lasso(max_iter=10000))]),
#              param_grid={'model__alpha': array([200.        , 201.66666667, 203.33333333, 205.        ])},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
alpha_tune_plot(four_search)

# %% [markdown]
# We have an idea that setting alpha to 200 in our lasso regression of SalePrice onto all of Ames data will yield our best performing model while avoiding overfitting.

# %%
coefs = four_search.best_estimator_[1].coef_
coefs
#cursory look at this is that a great deal of coefficients have been shrunk to 0.
# Out:
# array([ 1.34070748e+04,  1.38141824e+03,  2.69101150e+03, -7.06239641e+02,
#         1.96561649e+02,  1.97150665e+02,  1.30582393e+04,  6.35413133e+03,
#         7.21993643e+03,  4.32916160e+01,  4.86240509e+03,  5.08256864e+03,
#        -2.99723413e+02,  1.63743885e+03, -3.52110135e+03,  3.90986107e+03,
#        -6.38190101e+02,  8.36657689e+03,  0.00000000e+00,  1.58437150e+03,
#        -0.00000000e+00,  0.00000000e+00,  7.92236768e+02,  3.40428835e+02,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -1.28491533e+03,  0.00000000e+00, -4.07938232e+03, -1.57161494e+03,
#         4.72621626e+03,  0.00000000e+00,  1.96597939e+03,  5.98124646e+03,
#         1.10069408e+03, -2.62294772e+03,  6.08723593e+02,  2.95836621e+03,
#         3.06932191e+03, -0.00000000e+00, -0.00000000e+00,  3.73922753e+02,
#        -3.83561907e+02,  0.00000000e+00,  2.87430990e+01,  7.46646474e+02,
#        -2.68996598e+03,  4.45974551e+03, -0.00000000e+00, -1.33131113e+03,
#         9.99743968e+03,  4.07144939e+03, -0.00000000e+00, -0.00000000e+00,
#         7.63137577e+03, -3.21091720e+03,  4.76516353e+02, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  1.38694502e+04,  0.00000000e+00,
#        -0.00000000e+00, -8.32363620e+02, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  5.50282426e+03,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.01354944e+04,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -1.65952515e+03,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -4.07718468e+02,
#        -0.00000000e+00,  0.00000000e+00, -2.94842223e+03,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  1.79540112e+03,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -1.46852996e+03,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  6.27527541e+02,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  2.71139966e+03,
#         0.00000000e+00, -0.00000000e+00, -3.56868204e+01, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  4.69626469e+03,  0.00000000e+00,
#        -0.00000000e+00, -7.46841449e+02,  2.42187303e+02, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  2.85861896e+02,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  1.18372494e+02,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  5.59390137e+03,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  2.73290969e+03, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         1.27108406e+03, -0.00000000e+00,  0.00000000e+00, -1.65974212e+03,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  6.80004488e+02,  0.00000000e+00, -1.69500623e+03,
#         8.54690048e+03, -9.97684266e+02, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -1.55625613e+03,  0.00000000e+00, -1.75066646e+03,
#         1.73915353e+04,  2.51899695e+04, -1.55062537e+03, -0.00000000e+00,
#         0.00000000e+00, -2.58078039e+03,  9.47701920e+03,  3.01139819e+04,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  6.67624739e+02,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  1.67335450e+01,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  1.14812144e+04,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -1.50893473e+03, -0.00000000e+00,  0.00000000e+00,
#         1.98028471e+02, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00])

# %%
lasso_coefs = four_search.best_estimator_[1].coef_
feature_names = X.columns 
zero_coef_features = [feature_names[i] for i in range(len(lasso_coefs)) if lasso_coefs[i] == 0]

print(f"Number of features shrunk to zero: {len(zero_coef_features)}")
print("Features shrunk to zero by Lasso:")
for feature in zero_coef_features:
    print(feature)
# Out:
# Number of features shrunk to zero: 191
# Features shrunk to zero by Lasso:
# BsmtFinType2
# BsmtUnfSF
# TotalBsmtSF
# 2ndFlrSF
# LowQualFinSF
# BsmtFullBath
# BsmtHalfBath
# HalfBath
# TotRmsAbvGrd
# GarageQual
# GarageCond
# EnclosedPorch
# MiscVal
# yrsbtwn
# BedxBath
# Alley_Grvl
# Alley_No Alley
# Alley_Pave
# BldgType_2fmCon
# BldgType_Duplex
# BldgType_TwnhsE
# CentralAir_N
# CentralAir_Y
# Condition1_Artery
# Condition1_Feedr
# Condition1_PosA
# Condition1_PosN
# Condition1_RRAe
# Condition1_RRAn
# Condition1_RRNe
# Condition1_RRNn
# Condition2_Artery
# Condition2_Feedr
# Condition2_Norm
# Condition2_PosA
# Condition2_PosN
# Condition2_RRAe
# Condition2_RRAn
# Condition2_RRNn
# Electrical_FuseA
# Electrical_FuseF
# Electrical_FuseP
# Electrical_SBrkr
# Exterior1st_AsbShng
# Exterior1st_AsphShn
# Exterior1st_BrkComm
# Exterior1st_CBlock
# Exterior1st_CemntBd
# Exterior1st_HdBoard
# Exterior1st_ImStucc
# Exterior1st_MetalSd
# Exterior1st_Plywood
# Exterior1st_PreCast
# Exterior1st_Stucco
# Exterior1st_VinylSd
# Exterior1st_WdShing
# Exterior2nd_AsbShng
# Exterior2nd_AsphShn
# Exterior2nd_Brk Cmn
# Exterior2nd_BrkFace
# Exterior2nd_CBlock
# Exterior2nd_CmentBd
# Exterior2nd_ImStucc
# Exterior2nd_MetalSd
# Exterior2nd_PreCast
# Exterior2nd_Stone
# Exterior2nd_Stucco
# Exterior2nd_Wd Sdng
# Exterior2nd_Wd Shng
# Fence_GdPrv
# Fence_GdWo
# Fence_MnPrv
# Fence_MnWw
# Fence_No Fence
# Foundation_BrkTil
# Foundation_PConc
# Foundation_Slab
# Foundation_Stone
# Foundation_Wood
# GarageType_2Types
# GarageType_Attchd
# GarageType_Basment
# GarageType_BuiltIn
# GarageType_CarPort
# GarageType_No Garage
# Heating_Floor
# Heating_GasA
# Heating_GasW
# Heating_Grav
# Heating_OthW
# Heating_Wall
# HouseStyle_1.5Fin
# HouseStyle_1.5Unf
# HouseStyle_2.5Fin
# HouseStyle_2.5Unf
# HouseStyle_SFoyer
# HouseStyle_SLvl
# LandContour_Bnk
# LandContour_Low
# LandContour_Lvl
# LotConfig_FR2
# LotConfig_FR3
# LotConfig_Inside
# MSSubClass_120
# MSSubClass_150
# MSSubClass_160
# MSSubClass_180
# MSSubClass_190
# MSSubClass_30
# MSSubClass_40
# MSSubClass_45
# MSSubClass_50
# MSSubClass_60
# MSSubClass_70
# MSSubClass_75
# MSSubClass_80
# MSSubClass_85
# MSSubClass_90
# MSZoning_A (agr)
# MSZoning_C (all)
# MSZoning_FV
# MSZoning_I (all)
# MSZoning_RH
# MSZoning_RM
# MasVnrType_BrkCmn
# MasVnrType_BrkFace
# MasVnrType_Stone
# MiscFeature_Gar2
# MiscFeature_No Misc
# MiscFeature_Othr
# MiscFeature_Shed
# MiscFeature_TenC
# MoSold_2
# MoSold_3
# MoSold_4
# MoSold_5
# MoSold_6
# MoSold_8
# MoSold_9
# MoSold_11
# MoSold_12
# Neighborhood_Blmngtn
# Neighborhood_Blueste
# Neighborhood_BrDale
# Neighborhood_ClearCr
# Neighborhood_Gilbert
# Neighborhood_Greens
# Neighborhood_GrnHill
# Neighborhood_IDOTRR
# Neighborhood_Landmrk
# Neighborhood_MeadowV
# Neighborhood_Mitchel
# Neighborhood_NPkVill
# Neighborhood_SWISU
# Neighborhood_Sawyer
# Neighborhood_Timber
# Neighborhood_Veenker
# PavedDrive_1
# PavedDrive_2
# PavedDrive_3
# RoofMatl_CompShg
# RoofMatl_Membran
# RoofMatl_Metal
# RoofMatl_Roll
# RoofMatl_Tar&Grv
# RoofMatl_WdShake
# RoofStyle_Flat
# RoofStyle_Gable
# RoofStyle_Gambrel
# RoofStyle_Mansard
# RoofStyle_Shed
# SaleCondition_Abnorml
# SaleCondition_AdjLand
# SaleCondition_Alloca
# SaleCondition_Family
# SaleCondition_Normal
# SaleType_COD
# SaleType_CWD
# SaleType_Con
# SaleType_ConLD
# SaleType_ConLI
# SaleType_ConLw
# SaleType_New
# SaleType_Oth
# SaleType_VWD
# Street_Grvl
# Street_Pave
# YrSold_2007
# YrSold_2008
# YrSold_2009
# YrSold_2010

# %%
non_zero_coef_features = [feature_names[i] for i in range(len(lasso_coefs)) if lasso_coefs[i] != 0]
print(f"Number of features not shrunk to zero: {len(non_zero_coef_features)}")
print("Features not shrunk to zero by Lasso:")
for feature in non_zero_coef_features:
    print(feature)
# Out:
# Number of features not shrunk to zero: 82
# Features not shrunk to zero by Lasso:
# GrLivArea
# LotFrontage
# LotArea
# LotShape
# Utilities
# LandSlope
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# MasVnrArea
# ExterQual
# ExterCond
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinSF2
# HeatingQC
# 1stFlrSF
# FullBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# Functional
# Fireplaces
# FireplaceQu
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# WoodDeckSF
# OpenPorchSF
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# TotalBath
# TotalSF
# HQSF
# RoomsxBath
# FireplaceYN
# TotalPorchSF
# BldgType_1Fam
# BldgType_Twnhs
# Condition1_Norm
# Exterior1st_BrkFace
# Exterior1st_Wd Sdng
# Exterior2nd_HdBoard
# Exterior2nd_Plywood
# Exterior2nd_VinylSd
# Foundation_CBlock
# GarageType_Detchd
# HouseStyle_1Story
# HouseStyle_2Story
# LandContour_HLS
# LotConfig_Corner
# LotConfig_CulDSac
# MSSubClass_20
# MSZoning_RL
# MasVnrType_No MasVnr
# MoSold_1
# MoSold_7
# MoSold_10
# Neighborhood_BrkSide
# Neighborhood_CollgCr
# Neighborhood_Crawfor
# Neighborhood_Edwards
# Neighborhood_NAmes
# Neighborhood_NWAmes
# Neighborhood_NoRidge
# Neighborhood_NridgHt
# Neighborhood_OldTown
# Neighborhood_SawyerW
# Neighborhood_Somerst
# Neighborhood_StoneBr
# RoofMatl_WdShngl
# RoofStyle_Hip
# SaleCondition_Partial
# SaleType_WD
# YrSold_2006

# %%
#Characterize Non-zero Coefficient Features
#Recover General Names of Coefficients (pre-dummification)

orig_feature_names_list = []

for feature in non_zero_coef_features:
    orig_feature_names_list.append(feature.split('_')[0])

orig_feature_names_list = list(set(orig_feature_names_list)) #remove duplicates

print(f'Remaining Features: {len(orig_feature_names_list)}')
orig_feature_names_list
# Out:
# Remaining Features: 63
# ['ExterCond',
#  'HeatingQC',
#  'Foundation',
#  'LotConfig',
#  'FireplaceQu',
#  'LandContour',
#  'GarageFinish',
#  'MSSubClass',
#  'GarageType',
#  'ExterQual',
#  'MasVnrArea',
#  'SaleCondition',
#  'Fireplaces',
#  'OverallQual',
#  'GrLivArea',
#  '1stFlrSF',
#  'GarageArea',
#  'LotArea',
#  'LotFrontage',
#  'OverallCond',
#  'BsmtFinSF2',
#  'PoolQC',
#  'Utilities',
#  'TotalBath',
#  'HouseStyle',
#  'HQSF',
#  'MSZoning',
#  'FireplaceYN',
#  'SaleType',
#  'Functional',
#  'GarageCars',
#  'MasVnrType',
#  'YrSold',
#  'YearRemodAdd',
#  'PoolArea',
#  'Exterior2nd',
#  'BsmtExposure',
#  'RoomsxBath',
#  'FullBath',
#  'Condition1',
#  '3SsnPorch',
#  'ScreenPorch',
#  'Neighborhood',
#  'YearBuilt',
#  'BedroomAbvGr',
#  'RoofStyle',
#  'BsmtQual',
#  'KitchenQual',
#  'TotalPorchSF',
#  'MoSold',
#  'TotalSF',
#  'BsmtCond',
#  'Exterior1st',
#  'RoofMatl',
#  'BsmtFinType1',
#  'LandSlope',
#  'BldgType',
#  'KitchenAbvGr',
#  'GarageYrBlt',
#  'OpenPorchSF',
#  'BsmtFinSF1',
#  'WoodDeckSF',
#  'LotShape']

# %%
nominal_vars = []
ord_vars = []
num_vars = []

for feature in orig_feature_names_list:
    if feature in nominal_cols:
        nominal_vars.append(feature)
    elif feature in ordinal_cols:
        ord_vars.append(feature)
    else:
        num_vars.append(feature)

print(f"Nominal Features ({len(nominal_vars)}):", nominal_vars)
print(f"\nOrdinal Features ({len(ord_vars)}):", ord_vars)
print(f"\nNumeric Features ({len(num_vars)}):", num_vars)
# Out:
# Nominal Features (19): ['Foundation', 'LotConfig', 'LandContour', 'MSSubClass', 'GarageType', 'SaleCondition', 'HouseStyle', 'MSZoning', 'SaleType', 'MasVnrType', 'YrSold', 'Exterior2nd', 'Condition1', 'Neighborhood', 'RoofStyle', 'MoSold', 'Exterior1st', 'RoofMatl', 'BldgType']
#
# Ordinal Features (15): ['ExterCond', 'HeatingQC', 'FireplaceQu', 'GarageFinish', 'ExterQual', 'PoolQC', 'Utilities', 'Functional', 'BsmtExposure', 'BsmtQual', 'KitchenQual', 'BsmtCond', 'BsmtFinType1', 'LandSlope', 'LotShape']
#
# Numeric Features (29): ['MasVnrArea', 'Fireplaces', 'OverallQual', 'GrLivArea', '1stFlrSF', 'GarageArea', 'LotArea', 'LotFrontage', 'OverallCond', 'BsmtFinSF2', 'TotalBath', 'HQSF', 'FireplaceYN', 'GarageCars', 'YearRemodAdd', 'PoolArea', 'RoomsxBath', 'FullBath', '3SsnPorch', 'ScreenPorch', 'YearBuilt', 'BedroomAbvGr', 'TotalPorchSF', 'TotalSF', 'KitchenAbvGr', 'GarageYrBlt', 'OpenPorchSF', 'BsmtFinSF1', 'WoodDeckSF']

# %%
#Sort Variables by Magnitude of Coefficients (~Importance)
pd.set_option('display.max_rows', None)
coefs = search.best_estimator_.named_steps['model'].coef_
column_names = X_train.columns

coef_df = pd.DataFrame({'Coefficient': coefs, 'Feature': column_names})

coef_df_sorted = coef_df.reindex(coef_df['Coefficient'].abs().sort_values(ascending=False).index)

coef_df_sorted
# Out:
#       Coefficient                Feature
# 0    12086.135608              GrLivArea
# 6    12073.880352            OverallQual
# 17    8412.268762             BsmtFinSF1
# 52    7421.620516                TotalSF
# 225   7215.553046   Neighborhood_NridgHt
# 53    7071.944183                   HQSF
# 62    5787.567835          BldgType_1Fam
# 8     5603.325545              YearBuilt
# 231   4854.737270   Neighborhood_StoneBr
# 11    4775.636020              ExterQual
# 7     4730.373108            OverallCond
# 224   4600.736292   Neighborhood_NoRidge
# 56    4545.318413             RoomsxBath
# 32    4529.676752            KitchenQual
# 35    4074.055892             Fireplaces
# 15    3968.996330           BsmtExposure
# 243   3657.982988       RoofMatl_WdShngl
# 82   -3473.839189        Condition2_PosN
# 230   3470.066810   Neighborhood_Somerst
# 10    3323.734527             MasVnrArea
# 255   2870.640121  SaleCondition_Partial
# 30   -2692.751045           BedroomAbvGr
# 81    2683.339513        Condition2_PosA
# 216   2544.516228   Neighborhood_GrnHill
# 39    2436.080761             GarageCars
# 212   2346.197499   Neighborhood_Crawfor
# 2     2285.091416                LotArea
# 40    2224.282721             GarageArea
# 93    2162.944411    Exterior1st_BrkFace
# 49    2111.281185                 PoolQC
# 154   1580.413346        LandContour_HLS
# 71    1386.965397        Condition1_Norm
# 34    1310.811771             Functional
# 253  -1296.665171   SaleCondition_Family
# 118   1294.063160    Exterior2nd_VinylSd
# 19    1039.338698             BsmtFinSF2
# 14    -970.927828               BsmtCond
# 138    881.986925   GarageType_No Garage
# 1      799.726443            LotFrontage
# 129    766.067883        Foundation_Slab
# 23     753.275409               1stFlrSF
# 158    662.692009      LotConfig_CulDSac
# 65    -614.466656         BldgType_Twnhs
# 9      600.950497           YearRemodAdd
# 69    -590.965137      Condition1_Artery
# 223   -586.294117    Neighborhood_NWAmes
# 22     585.427818              HeatingQC
# 187    546.801900   MasVnrType_No MasVnr
# 194    502.858591               MoSold_1
# 103   -471.986673    Exterior1st_Wd Sdng
# 143   -462.900130           Heating_OthW
# 226   -444.496549   Neighborhood_OldTown
# 31    -431.337909           KitchenAbvGr
# 114   -411.164130    Exterior2nd_Plywood
# 58     409.025485           TotalPorchSF
# 209    407.066044   Neighborhood_BrkSide
# 221   -389.198420     Neighborhood_NAmes
# 134   -381.867747     GarageType_Basment
# 38     342.049382           GarageFinish
# 70    -324.724735       Condition1_Feedr
# 248   -295.835699      RoofStyle_Mansard
# 258    292.949809           SaleType_Con
# 247    242.995125          RoofStyle_Hip
# 127   -236.592787      Foundation_CBlock
# 13     232.695753               BsmtQual
# 203   -225.215521              MoSold_10
# 193   -220.751225       MiscFeature_TenC
# 229   -174.419534   Neighborhood_SawyerW
# 3     -172.336368               LotShape
# 186   -149.899071     MasVnrType_BrkFace
# 128    139.206230       Foundation_PConc
# 167    134.995479          MSSubClass_20
# 47      61.615402            ScreenPorch
# 200     43.679095               MoSold_7
# 238     34.428837       RoofMatl_Membran
# 183     33.849843            MSZoning_RL
# 250    -31.943653  SaleCondition_Abnorml
# 222     31.076632   Neighborhood_NPkVill
# 5       22.281200              LandSlope
# 178      0.000000       MSZoning_A (agr)
# 179     -0.000000       MSZoning_C (all)
# 184     -0.000000            MSZoning_RM
# 199     -0.000000               MoSold_6
# 182     -0.000000            MSZoning_RH
# 198      0.000000               MoSold_5
# 197     -0.000000               MoSold_4
# 164     -0.000000         MSSubClass_160
# 196     -0.000000               MoSold_3
# 165      0.000000         MSSubClass_180
# 166      0.000000         MSSubClass_190
# 195     -0.000000               MoSold_2
# 181      0.000000       MSZoning_I (all)
# 201     -0.000000               MoSold_8
# 168      0.000000          MSSubClass_30
# 192     -0.000000       MiscFeature_Shed
# 169     -0.000000          MSSubClass_40
# 191      0.000000       MiscFeature_Othr
# 190      0.000000    MiscFeature_No Misc
# 189      0.000000       MiscFeature_Gar2
# 170     -0.000000          MSSubClass_45
# 185     -0.000000      MasVnrType_BrkCmn
# 171      0.000000          MSSubClass_50
# 172      0.000000          MSSubClass_60
# 173     -0.000000          MSSubClass_70
# 174      0.000000          MSSubClass_75
# 188      0.000000       MasVnrType_Stone
# 175     -0.000000          MSSubClass_80
# 176     -0.000000          MSSubClass_85
# 177     -0.000000          MSSubClass_90
# 180      0.000000            MSZoning_FV
# 228      0.000000    Neighborhood_Sawyer
# 202      0.000000               MoSold_9
# 260      0.000000         SaleType_ConLI
# 244      0.000000         RoofStyle_Flat
# 245     -0.000000        RoofStyle_Gable
# 246     -0.000000      RoofStyle_Gambrel
# 249      0.000000         RoofStyle_Shed
# 251     -0.000000  SaleCondition_AdjLand
# 252      0.000000   SaleCondition_Alloca
# 254      0.000000   SaleCondition_Normal
# 256     -0.000000           SaleType_COD
# 257      0.000000           SaleType_CWD
# 259      0.000000         SaleType_ConLD
# 261      0.000000         SaleType_ConLw
# 204     -0.000000              MoSold_11
# 262      0.000000           SaleType_New
# 263      0.000000           SaleType_Oth
# 264      0.000000           SaleType_VWD
# 265     -0.000000           SaleType_WD
# 266     -0.000000            Street_Grvl
# 267      0.000000            Street_Pave
# 268      0.000000            YrSold_2006
# 269     -0.000000            YrSold_2007
# 270      0.000000            YrSold_2008
# 271     -0.000000            YrSold_2009
# 242      0.000000       RoofMatl_WdShake
# 241     -0.000000       RoofMatl_Tar&Grv
# 240     -0.000000          RoofMatl_Roll
# 239      0.000000         RoofMatl_Metal
# 205     -0.000000              MoSold_12
# 206     -0.000000   Neighborhood_Blmngtn
# 207      0.000000   Neighborhood_Blueste
# 208      0.000000    Neighborhood_BrDale
# 210      0.000000   Neighborhood_ClearCr
# 211     -0.000000   Neighborhood_CollgCr
# 213     -0.000000   Neighborhood_Edwards
# 214      0.000000   Neighborhood_Gilbert
# 215     -0.000000    Neighborhood_Greens
# 217      0.000000    Neighborhood_IDOTRR
# 218      0.000000   Neighborhood_Landmrk
# 219      0.000000   Neighborhood_MeadowV
# 220     -0.000000   Neighborhood_Mitchel
# 227     -0.000000     Neighborhood_SWISU
# 162     -0.000000         MSSubClass_120
# 232      0.000000    Neighborhood_Timber
# 233      0.000000   Neighborhood_Veenker
# 234      0.000000           PavedDrive_1
# 235     -0.000000           PavedDrive_2
# 236      0.000000           PavedDrive_3
# 237     -0.000000       RoofMatl_CompShg
# 163     -0.000000         MSSubClass_150
# 136      0.000000     GarageType_CarPort
# 161      0.000000       LotConfig_Inside
# 76      -0.000000        Condition1_RRNe
# 60       0.000000         Alley_No Alley
# 61      -0.000000             Alley_Pave
# 63       0.000000        BldgType_2fmCon
# 64      -0.000000        BldgType_Duplex
# 66      -0.000000        BldgType_TwnhsE
# 67       0.000000           CentralAir_N
# 68      -0.000000           CentralAir_Y
# 72       0.000000        Condition1_PosA
# 73       0.000000        Condition1_PosN
# 74      -0.000000        Condition1_RRAe
# 75       0.000000        Condition1_RRAn
# 77       0.000000        Condition1_RRNn
# 57      -0.000000            FireplaceYN
# 78       0.000000      Condition2_Artery
# 79      -0.000000       Condition2_Feedr
# 80       0.000000        Condition2_Norm
# 83      -0.000000        Condition2_RRAe
# 84      -0.000000        Condition2_RRAn
# 85       0.000000        Condition2_RRNn
# 86      -0.000000       Electrical_FuseA
# 87       0.000000       Electrical_FuseF
# 88       0.000000       Electrical_FuseP
# 89      -0.000000       Electrical_SBrkr
# 90      -0.000000    Exterior1st_AsbShng
# 59      -0.000000             Alley_Grvl
# 55      -0.000000               BedxBath
# 92       0.000000    Exterior1st_BrkComm
# 29       0.000000               HalfBath
# 4        0.000000              Utilities
# 12      -0.000000              ExterCond
# 16      -0.000000           BsmtFinType1
# 18       0.000000           BsmtFinType2
# 20      -0.000000              BsmtUnfSF
# 21       0.000000            TotalBsmtSF
# 24       0.000000               2ndFlrSF
# 25      -0.000000           LowQualFinSF
# 26       0.000000           BsmtFullBath
# 27       0.000000           BsmtHalfBath
# 28      -0.000000               FullBath
# 33       0.000000           TotRmsAbvGrd
# 54      -0.000000                yrsbtwn
# 36       0.000000            FireplaceQu
# 37      -0.000000            GarageYrBlt
# 41      -0.000000             GarageQual
# 42      -0.000000             GarageCond
# 43       0.000000             WoodDeckSF
# 44      -0.000000            OpenPorchSF
# 45      -0.000000          EnclosedPorch
# 46       0.000000              3SsnPorch
# 48      -0.000000               PoolArea
# 50      -0.000000                MiscVal
# 51       0.000000              TotalBath
# 91       0.000000    Exterior1st_AsphShn
# 94       0.000000     Exterior1st_CBlock
# 160     -0.000000          LotConfig_FR3
# 145     -0.000000      HouseStyle_1.5Fin
# 130     -0.000000       Foundation_Stone
# 131     -0.000000        Foundation_Wood
# 132     -0.000000      GarageType_2Types
# 133     -0.000000      GarageType_Attchd
# 135      0.000000     GarageType_BuiltIn
# 137     -0.000000      GarageType_Detchd
# 139      0.000000          Heating_Floor
# 140     -0.000000           Heating_GasA
# 141      0.000000           Heating_GasW
# 142      0.000000           Heating_Grav
# 144      0.000000           Heating_Wall
# 146      0.000000      HouseStyle_1.5Unf
# 125      0.000000         Fence_No Fence
# 147      0.000000      HouseStyle_1Story
# 148      0.000000      HouseStyle_2.5Fin
# 149     -0.000000      HouseStyle_2.5Unf
# 150     -0.000000      HouseStyle_2Story
# 151     -0.000000      HouseStyle_SFoyer
# 152     -0.000000        HouseStyle_SLvl
# 153     -0.000000        LandContour_Bnk
# 155      0.000000        LandContour_Low
# 156     -0.000000        LandContour_Lvl
# 157     -0.000000       LotConfig_Corner
# 159     -0.000000          LotConfig_FR2
# 126     -0.000000      Foundation_BrkTil
# 124     -0.000000             Fence_MnWw
# 95       0.000000    Exterior1st_CemntBd
# 108      0.000000    Exterior2nd_BrkFace
# 96      -0.000000    Exterior1st_HdBoard
# 97      -0.000000    Exterior1st_ImStucc
# 98       0.000000    Exterior1st_MetalSd
# 99      -0.000000    Exterior1st_Plywood
# 100      0.000000    Exterior1st_PreCast
# 101      0.000000     Exterior1st_Stucco
# 102      0.000000    Exterior1st_VinylSd
# 104     -0.000000    Exterior1st_WdShing
# 105     -0.000000    Exterior2nd_AsbShng
# 106      0.000000    Exterior2nd_AsphShn
# 107      0.000000    Exterior2nd_Brk Cmn
# 109      0.000000     Exterior2nd_CBlock
# 123     -0.000000            Fence_MnPrv
# 110      0.000000    Exterior2nd_CmentBd
# 111     -0.000000    Exterior2nd_HdBoard
# 112      0.000000    Exterior2nd_ImStucc
# 113      0.000000    Exterior2nd_MetalSd
# 115      0.000000    Exterior2nd_PreCast
# 116      0.000000      Exterior2nd_Stone
# 117      0.000000     Exterior2nd_Stucco
# 119     -0.000000    Exterior2nd_Wd Sdng
# 120     -0.000000    Exterior2nd_Wd Shng
# 121      0.000000            Fence_GdPrv
# 122      0.000000             Fence_GdWo
# 272      0.000000            YrSold_2010

# %%
#Calculate best alpha with all non-zero features
X = ames_lasso_encoded_nodrop.drop(columns = ['PID', 'SalePrice'], axis = 1)
X = X.drop(columns = zero_coef_features)
y = ames_lasso_encoded_nodrop['SalePrice']

# %%
#Redefine cols_to_scale
cols_to_scale1 = []        
for col_name in non_zero_coef_features:
    if "_" not in col_name:
        cols_to_scale1.append(col_name)

# %%
#Grid Search Setup
param_grid = {'model__alpha': np.logspace(-1, 4, 100)}
pipeline = Pipeline([
    ('scaler', SubsetScaler(cols_to_scale1)), #SubsetScaler
    ('model', Lasso(max_iter = 10000))
])

# %%
#Calculate Best Alpha for R2 with all non-zero features

trimmed_search = GridSearchCV(pipeline, param_grid, cv = 5, scoring = 'r2', return_train_score = True)

trimmed_search.fit(X, y)

# Extract Scores and Alphas to Plot
train_scores = trimmed_search.cv_results_['mean_train_score']
test_scores = trimmed_search.cv_results_['mean_test_score']
alphas = param_grid['model__alpha']

# Plotting
plt.figure(figsize=(10, 6))
plt.semilogx(alphas, train_scores, label='Train')
plt.semilogx(alphas, test_scores, label='Test')
plt.xlabel('Alpha')
plt.ylabel('R² Score')
plt.title('R² Score vs. Alpha in Lasso Regression')
plt.legend()
plt.show()

# Print the best parameters and best R-squared score
print("Best parameters:", trimmed_search.best_params_)
print("Best R-squared:", trimmed_search.best_score_)
# Out:
# Best parameters: {'model__alpha': 21.049041445120196}
# Best R-squared: 0.904842356659844

# %%
alpha_tune_plot(trimmed_search)

# %%
#Zoom in on alpha
param_grid = {'model__alpha': np.linspace(0.01, 50, 50)}

# %%
#Calculate Best Alpha for R2 with all non-zero features

trimmed_search = GridSearchCV(pipeline, param_grid, cv = 5, scoring = 'r2', return_train_score = True)

trimmed_search.fit(X, y)

# Extract Scores and Alphas to Plot
train_scores = trimmed_search.cv_results_['mean_train_score']
test_scores = trimmed_search.cv_results_['mean_test_score']
alphas = param_grid['model__alpha']

# Plotting
plt.figure(figsize=(10, 6))
plt.semilogx(alphas, train_scores, label='Train')
plt.semilogx(alphas, test_scores, label='Test')
plt.xlabel('Alpha')
plt.ylabel('R² Score')
plt.title('R² Score vs. Alpha in Lasso Regression')
plt.legend()
plt.show()

# Print the best parameters and best R-squared score
print("Best parameters:", trimmed_search.best_params_)
print("Best R-squared:", trimmed_search.best_score_)
# Out:
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.967e+11, tolerance: 1.090e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.742e+11, tolerance: 1.096e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.174e+11, tolerance: 1.190e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.296e+11, tolerance: 1.220e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.178e+11, tolerance: 1.209e+09 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# Best parameters: {'model__alpha': 20.408163265306122}
# Best R-squared: 0.9048424228749663

# %%
np.logspace(-1, 4, 100)
# Out:
# array([1.00000000e-01, 1.12332403e-01, 1.26185688e-01, 1.41747416e-01,
#        1.59228279e-01, 1.78864953e-01, 2.00923300e-01, 2.25701972e-01,
#        2.53536449e-01, 2.84803587e-01, 3.19926714e-01, 3.59381366e-01,
#        4.03701726e-01, 4.53487851e-01, 5.09413801e-01, 5.72236766e-01,
#        6.42807312e-01, 7.22080902e-01, 8.11130831e-01, 9.11162756e-01,
#        1.02353102e+00, 1.14975700e+00, 1.29154967e+00, 1.45082878e+00,
#        1.62975083e+00, 1.83073828e+00, 2.05651231e+00, 2.31012970e+00,
#        2.59502421e+00, 2.91505306e+00, 3.27454916e+00, 3.67837977e+00,
#        4.13201240e+00, 4.64158883e+00, 5.21400829e+00, 5.85702082e+00,
#        6.57933225e+00, 7.39072203e+00, 8.30217568e+00, 9.32603347e+00,
#        1.04761575e+01, 1.17681195e+01, 1.32194115e+01, 1.48496826e+01,
#        1.66810054e+01, 1.87381742e+01, 2.10490414e+01, 2.36448941e+01,
#        2.65608778e+01, 2.98364724e+01, 3.35160265e+01, 3.76493581e+01,
#        4.22924287e+01, 4.75081016e+01, 5.33669923e+01, 5.99484250e+01,
#        6.73415066e+01, 7.56463328e+01, 8.49753436e+01, 9.54548457e+01,
#        1.07226722e+02, 1.20450354e+02, 1.35304777e+02, 1.51991108e+02,
#        1.70735265e+02, 1.91791026e+02, 2.15443469e+02, 2.42012826e+02,
#        2.71858824e+02, 3.05385551e+02, 3.43046929e+02, 3.85352859e+02,
#        4.32876128e+02, 4.86260158e+02, 5.46227722e+02, 6.13590727e+02,
#        6.89261210e+02, 7.74263683e+02, 8.69749003e+02, 9.77009957e+02,
#        1.09749877e+03, 1.23284674e+03, 1.38488637e+03, 1.55567614e+03,
#        1.74752840e+03, 1.96304065e+03, 2.20513074e+03, 2.47707636e+03,
#        2.78255940e+03, 3.12571585e+03, 3.51119173e+03, 3.94420606e+03,
#        4.43062146e+03, 4.97702356e+03, 5.59081018e+03, 6.28029144e+03,
#        7.05480231e+03, 7.92482898e+03, 8.90215085e+03, 1.00000000e+04])

# %%
#Calculate Best Alpha for RMSE with all non-zero features
# Define feature matrix X and target y

param_grid = {'model__alpha': np.logspace(-1, 4, 100)}
pipeline = Pipeline([
    ('scaler', SubsetScaler(cols_to_scale1)),
    ('model', Lasso(max_iter=10000))
])

# Initialize GridSearchCV with return_train_score=True to get the training scores
rmse_search = GridSearchCV(pipeline, param_grid, cv= 5, scoring='neg_mean_squared_error', return_train_score=True)

# Perform grid search
rmse_search.fit(X, y)

# Extract the negative mean squared errors and convert them to RMSE
train_rmse_scores = np.sqrt(-rmse_search.cv_results_['mean_train_score'])
test_rmse_scores = np.sqrt(-rmse_search.cv_results_['mean_test_score'])
alphas = param_grid['model__alpha']

# Plotting
plt.figure(figsize=(10, 6))
plt.semilogx(alphas, train_rmse_scores, label='Train RMSE')
plt.semilogx(alphas, test_rmse_scores, label='Test RMSE')
plt.xlabel('Alpha')
plt.ylabel('RMSE')
plt.title('RMSE vs. Alpha in Lasso Regression')
plt.legend()
plt.show()

# Print the best parameters and corresponding RMSE
best_alpha_index = np.argmin(test_rmse_scores)
best_alpha = alphas[best_alpha_index]
best_rmse = test_rmse_scores[best_alpha_index]
print(f"Best alpha: {best_alpha}")
print(f"Best RMSE: {best_rmse}")
# Out:
# Best alpha: 6.579332246575679
# Best RMSE: 23404.41901210851

# %%
#Zoom in again
param_grid = {'model__alpha': np.linspace(1, 10, 9)}

# %%
# Initialize GridSearchCV with return_train_score=True to get the training scores
rmse_search = GridSearchCV(pipeline, param_grid, cv= 5, scoring='neg_mean_squared_error', return_train_score=True)

# Perform grid search
rmse_search.fit(X, y)

# Extract the negative mean squared errors and convert them to RMSE
train_rmse_scores = np.sqrt(-rmse_search.cv_results_['mean_train_score'])
test_rmse_scores = np.sqrt(-rmse_search.cv_results_['mean_test_score'])
alphas = param_grid['model__alpha']

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(alphas, train_rmse_scores, label='Train RMSE')
plt.plot(alphas, test_rmse_scores, label='Test RMSE')
plt.xlabel('Alpha')
plt.ylabel('RMSE')
plt.title('RMSE vs. Alpha in Lasso Regression')
plt.legend()
plt.show()

# Print the best parameters and corresponding RMSE
best_alpha_index = np.argmin(test_rmse_scores)
best_alpha = alphas[best_alpha_index]
best_rmse = test_rmse_scores[best_alpha_index]
print(f"Best alpha: {best_alpha}")
print(f"Best RMSE: {best_rmse}")
# Out:
# Best alpha: 6.625
# Best RMSE: 23404.416612231475

# %%
X.columns
# Out:
# Index(['GrLivArea', 'LotFrontage', 'LotArea', 'LotShape', 'Utilities',
#        'LandSlope', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinSF2', 'HeatingQC',
#        '1stFlrSF', 'FullBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'TotalBath',
#        'TotalSF', 'HQSF', 'RoomsxBath', 'FireplaceYN', 'TotalPorchSF',
#        'BldgType_1Fam', 'BldgType_Twnhs', 'Condition1_Norm',
#        'Exterior1st_BrkFace', 'Exterior1st_Wd Sdng', 'Exterior2nd_HdBoard',
#        'Exterior2nd_Plywood', 'Exterior2nd_VinylSd', 'Foundation_CBlock',
#        'GarageType_Detchd', 'HouseStyle_1Story', 'HouseStyle_2Story',
#        'LandContour_HLS', 'LotConfig_Corner', 'LotConfig_CulDSac',
#        'MSSubClass_20', 'MSZoning_RL', 'MasVnrType_No MasVnr', 'MoSold_1',
#        'MoSold_7', 'MoSold_10', 'Neighborhood_BrkSide', 'Neighborhood_CollgCr',
#        'Neighborhood_Crawfor', 'Neighborhood_Edwards', 'Neighborhood_NAmes',
#        'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 'Neighborhood_NridgHt',
#        'Neighborhood_OldTown', 'Neighborhood_SawyerW', 'Neighborhood_Somerst',
#        'Neighborhood_StoneBr', 'RoofMatl_WdShngl', 'RoofStyle_Hip',
#        'SaleCondition_Partial', 'SaleType_WD ', 'YrSold_2006'],
#       dtype='object')

# %%
#Lasso Coefficient Plot- way to make this look a bit nicer?

numeric_scaler = SubsetScaler(cols_to_scale1)
X_scaled = numeric_scaler.fit_transform(X)

#Alphas
alphas = np.logspace(-1, 5, 200)

#Store Coefficients
coefs = []
for alpha in alphas:
    model = Lasso(alpha = alpha, max_iter=10000)
    model.fit(X_scaled, y)
    coefs.append(model.coef_)

#Plot
plt.figure(figsize=(22, 30))
ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.xlabel('Alpha')
plt.ylabel('Coefficients')
plt.title('Lasso Path')
plt.axis('tight')

plt.legend(X.columns[:50], loc='upper right', bbox_to_anchor=(1.05, 1), fontsize='large')
plt.show()

# %%
# Define the number of subplots and the number of columns per subplot
num_subplots = 4
cols_per_subplot = 20

# Calculate the total number of columns
total_cols = len(X.columns)

# Calculate the number of columns per subplot
cols_per_subplot = min(cols_per_subplot, total_cols // num_subplots)

# Create subplots
fig, axes = plt.subplots(num_subplots, 1, figsize=(15, 20), sharex=True)

# Alphas
alphas = np.logspace(-1, 5, 200)

# Store Coefficients
coefs = []
for alpha in alphas:
    model = Lasso(alpha=alpha, max_iter=10000)
    model.fit(X_scaled, y)
    coefs.append(model.coef_)

# Plot each subset of columns on a separate subplot
legend_labels = []
for i, ax in enumerate(axes):
    start_idx = i * cols_per_subplot
    end_idx = min((i + 1) * cols_per_subplot, total_cols)
    lines = ax.plot(alphas, np.array(coefs)[:, start_idx:end_idx])
    legend_labels.extend(lines)
    ax.set_xscale('log')
    ax.set_ylabel('Coefficients')
    ax.set_title(f'Lasso Path (Columns {start_idx + 1}-{end_idx})')

# Set common x-axis label
axes[-1].set_xlabel('Alpha')

# Create a common legend outside of the subplots
fig.legend(legend_labels, X.columns[:total_cols], loc='upper right', bbox_to_anchor=(1.1, 1), fontsize='large')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
#Applying best alpha with kfold5 and dropping coefficients that dropped to 0.
#Now running lasso with the best parameters (alpha) and the most relevant features.

# Initialize the KFold cross-validator
kf = KFold(n_splits=5, shuffle=True, random_state=0)

# Initialize a StandardScaler
scaler = StandardScaler()

# Initialize Lasso with the specified alpha #120 alpha vs best alpha 271
lasso = Lasso(alpha=20, random_state=0)

# Lists to store RMSE and R2 scores for each fold
rmse_scores = []
r2_scores = []

# KFold cross-validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Scaling features
    X_train_scaled = scaler.fit_transform(X_train[cols_to_scale1])
    X_test_scaled = scaler.transform(X_test[cols_to_scale1])

    # Fit Lasso model
    lasso.fit(X_train_scaled, y_train)

    # Make predictions
    y_pred = lasso.predict(X_test_scaled)

    # Calculate RMSE and R2 for this fold and store them
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    rmse_scores.append(rmse)
    r2_scores.append(r2)

    # Print RMSE and R2 for each fold
    print(f"Fold {train_index}: RMSE = {rmse:.4f}, R2 = {r2:.4f}")

# Calculate and print the mean RMSE and R2 across all folds
mean_rmse = np.mean(rmse_scores)
mean_r2 = np.mean(r2_scores)
print(f"\nMean RMSE: {mean_rmse:.4f}")
print(f"Mean R2: {mean_r2:.4f}")

#cell below- add residuals info
# Out:
# Fold [   0    1    2 ... 2577 2578 2579]: RMSE = 25944.7666, R2 = 0.8935
# Fold [   0    2    3 ... 2577 2578 2579]: RMSE = 29948.2182, R2 = 0.7946
# Fold [   0    1    3 ... 2575 2576 2579]: RMSE = 22509.2586, R2 = 0.9169
# Fold [   0    1    2 ... 2576 2577 2578]: RMSE = 22856.6375, R2 = 0.8932
# Fold [   1    2    4 ... 2577 2578 2579]: RMSE = 29181.2854, R2 = 0.8673
#
# Mean RMSE: 26088.0333
# Mean R2: 0.8731

# %%
#Applying best alpha with kfold5 and dropping coefficients that dropped to 0.
#Now running lasso with the best parameters (alpha) and the most relevant features.

#Store info about residuals to plot
all_y_pred = []
all_y_actual = []
residuals = []

# Initialize the KFold cross-validator
kf = KFold(n_splits=5, shuffle=True, random_state=0)

# Initialize a StandardScaler
scaler = StandardScaler()

# Initialize Lasso with the specified alpha #120 alpha vs best alpha 271
lasso = Lasso(alpha=20, random_state=0)

# Lists to store RMSE and R2 scores for each fold
rmse_scores = []
r2_scores = []

# KFold cross-validation
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Scaling features
    X_train_scaled = scaler.fit_transform(X_train[cols_to_scale1])
    X_test_scaled = scaler.transform(X_test[cols_to_scale1])

    # Fit Lasso model
    lasso.fit(X_train_scaled, y_train)

    # Make predictions
    y_pred = lasso.predict(X_test_scaled)

    #Residuals info to plot
    all_y_pred.extend(y_pred)
    all_y_actual.extend(y_test.values)
    residuals.extend(y_test.values - y_pred)
    
    # Calculate RMSE and R2 for this fold and store them
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    rmse_scores.append(rmse)
    r2_scores.append(r2)

    # Print RMSE and R2 for each fold
    print(f"Fold {train_index}: RMSE = {rmse:.4f}, R2 = {r2:.4f}")

# Calculate and print the mean RMSE and R2 across all folds
mean_rmse = np.mean(rmse_scores)
mean_r2 = np.mean(r2_scores)
print(f"\nMean RMSE: {mean_rmse:.4f}")
print(f"Mean R2: {mean_r2:.4f}")
# Out:
# Fold [   0    1    2 ... 2577 2578 2579]: RMSE = 25944.7666, R2 = 0.8935
# Fold [   0    2    3 ... 2577 2578 2579]: RMSE = 29948.2182, R2 = 0.7946
# Fold [   0    1    3 ... 2575 2576 2579]: RMSE = 22509.2586, R2 = 0.9169
# Fold [   0    1    2 ... 2576 2577 2578]: RMSE = 22856.6375, R2 = 0.8932
# Fold [   1    2    4 ... 2577 2578 2579]: RMSE = 29181.2854, R2 = 0.8673
#
# Mean RMSE: 26088.0333
# Mean R2: 0.8731

# %%
# Visualization of Predicted vs Actual Sale Prices
plt.figure(figsize=(10, 6))
plt.scatter(all_y_pred, all_y_actual, alpha=0.5)
plt.title('Predicted vs Actual Sale Prices')
plt.xlabel('Predicted Sale Price')
plt.ylabel('Actual Sale Price')
plt.plot([min(all_y_actual), max(all_y_actual)], [min(all_y_actual), max(all_y_actual)], color='red', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(all_y_actual, residuals, alpha=0.5)
plt.title('Residuals of Actual vs Predicted Sale Prices')
plt.xlabel('Actual Sale Price')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.show()

# %%
def lasso_residuals_plot(featurelist, x, y):
    myX = x[featurelist]
    myY = y
    
    scaler = SubsetScaler(cols_to_scale1)
    myX_scaled = scaler.fit_transform(myX)

    lasso = Lasso(alpha=20, random_state=0)
    
    y_pred = cross_val_predict(lasso, myX, myY, cv = 5)
    
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=2580,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title(f"Actual vs. Predicted Values: {len(featurelist)} features")
    PredictionErrorDisplay.from_predictions(
        y,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=2580,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title(f"Residuals vs. Predicted Values: {len(featurelist)} features")
    fig.suptitle("Plotting cross-validated predictions")
    plt.tight_layout()
    plt.show()

lasso_residuals_plot(non_zero_coef_features, X, y)
# Out:
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.099e+11, tolerance: 1.090e+09
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.832e+11, tolerance: 1.096e+09
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.228e+11, tolerance: 1.190e+09
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.410e+11, tolerance: 1.220e+09
#   model = cd_fast.enet_coordinate_descent(
# /Users/joesferra/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.280e+11, tolerance: 1.209e+09
#   model = cd_fast.enet_coordinate_descent(

# %%
#Lasso is designed to be more robust to outliers than multiple linear regression. What if we remove outliers here?

#Redefining here for clarity
X_total = ames_lasso_encoded_nodrop.drop(columns = ['PID', 'SalePrice'], axis = 1)
X_total = X_total.drop(columns = zero_coef_features, axis = 1)
y_total = ames_lasso_encoded_nodrop['SalePrice']

#Store info about residuals to plot
all_y_pred = []
all_y_actual = []
residuals = []

#Scale
scaler_total = SubsetScaler(cols_to_scale1)
X_total_scaled = scaler_total.fit_transform(X_total)

#Run Lasso
lasso_total = Lasso(alpha = 20, max_iter = 10000)
lasso_total.fit(X_total_scaled, y_total)

y_pred_total = lasso_total.predict(X_total_scaled)

residuals_total = y_total - y_pred_total

results_df = ames_lasso_encoded_nodrop.copy()
results_df['PredictedPrice'] = y_pred_total
results_df['Residuals'] = residuals_total

#Remove and store outliers
outlier_rows=results_df[abs(results_df['Residuals']) > 40000]

outliers_removed = results_df[abs(results_df['Residuals']) <= 40000]

X_clean = outliers_removed.drop(['PredictedPrice', 'Residuals'], axis = 1)
y_clean = X_clean['SalePrice']
X_clean = X_clean.drop(columns = ['SalePrice'], axis = 1)
X_clean = X_clean.drop(zero_coef_features, axis=1)


kf = KFold(n_splits=5, shuffle=True, random_state= 0)

scaler = SubsetScaler(cols_to_scale1)

rmses = []
r2s = []

for fold, (train_index, test_index) in enumerate(kf.split(X_clean)):
    X_train, X_test = X_clean.iloc[train_index], X_clean.iloc[test_index]
    y_train, y_test = y_clean.iloc[train_index], y_clean.iloc[test_index]
    
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    lasso = Lasso(alpha = 20, max_iter = 10000)
    lasso.fit(X_train_scaled, y_train)
    
    y_pred = lasso.predict(X_test_scaled)
    
    #Residuals info to plot
    all_y_pred.extend(y_pred)
    all_y_actual.extend(y_test.values)
    residuals.extend(y_test.values - y_pred)
    
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    rmses.append(rmse)
    r2s.append(r2)
    
    print(f"{fold=}, {rmse=}, {r2=}")

mean_rmse = np.mean(rmses)
mean_r2 = np.mean(r2s)

print(f"\n{mean_rmse=}\n")
print(f"{mean_r2=}")

#How does the lasso perform on non-outliers? Quite well, with a mean R2 of .946.
# Out:
# fold=0, rmse=14548.964772841382, r2=0.9501637388413464
# fold=1, rmse=15065.12330901482, r2=0.9436424503382252
# fold=2, rmse=15724.206736723503, r2=0.9453203775081396
# fold=3, rmse=15253.249325715275, r2=0.9467426590787986
# fold=4, rmse=14514.559092111167, r2=0.9445979862636591
#
# mean_rmse=15021.220647281229
#
# mean_r2=0.9460934424060337

# %%
plt.figure(figsize=(10, 6))
plt.scatter(all_y_actual, residuals, alpha=0.5)
plt.title('Residuals of Actual vs Predicted Sale Prices')
plt.xlabel('Actual Sale Price')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.show()

# %%
def snshist(colname, framename, plotx = 14, ploty = 7, bins = 30): #detailed histogram
    "makes clean histograms with stats summaries:\
    colname: string of column name in chosen dataframe\
    framename: non-string, name of dataframe\
    plotx: horizontal size of plot\
    ploty: vertical size of plot\
    bins: binsinhistogram"
    
    col = framename[colname]
    
    mean = col.mean()
    median = col.median()
    mode = col.mode().values[0]
    plt.figure(figsize=(plotx, ploty))
    sns.histplot(x = col.values, bins=bins, kde=True, color='skyblue')
    plt.axvline(mean, color='r', linestyle='--', label=f"Mean: {mean:.2f}")
    plt.axvline(median, color='g', linestyle='-', label=f"Median: {median:.2f}")
    plt.axvline(mode, color='b', linestyle='-.', label=f"Mode: {mode:.2f}")
    
    plt.annotate(f"Skewness: {col.skew():.2f}\nKurtosis: {col.kurt():.2f}", xy = (.85, .1), xycoords = 'axes fraction',
                 fontsize = 14, bbox = dict(boxstyle="round,pad=.3", edgecolor="black", facecolor="aliceblue"))

    plt.title(f"Histogram of {colname} with KDE and Reference Lines")
    plt.xlabel(f"{colname}")
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# %%
#What about these outlier homes lead to them being outliers?
outlier_rows
# Out:
#            PID  GrLivArea  SalePrice  LotFrontage  LotArea  LotShape  \
# 30   528106110       2046     450000   105.000000    15431         4
# 55   904301060       1200     179000    60.000000    10800         4
# 57   528110070       1973     395000   110.000000    14226         4
# 66   528164060       2470     615000   106.000000    12720         4
# 74   911370410       1652     392500    64.000000     5587         3
# 104  528441090       2490     468000    85.000000    11128         4
# 109  528118050       2290     500067    59.000000    17169         2
# 110  916253320       1502     330000    69.287073     9763         3
# 112  533236050       1739     172500    24.000000     2645         4
# 117  902408080       2554     159500    60.000000    10800         4
# 125  906412010       2276     475000    91.000000    11778         4
# 174  528429120       2097     423000    49.000000    20896         2
# 181  527326040       1411      82500    85.000000    11900         4
# 183  527182170       2090     207500    60.666667     5062         3
# 203  907420090       1310     164990    65.000000     8767         3
# 208  527140090       1337     180000    41.000000     5395         3
# 217  533215040       1419     290000    42.000000     4385         3
# 237  906475110       2087     187500    89.764706    12205         3
# 247  911370460       1625     235000    44.000000     4750         3
# 255  902332030       2291     133900    60.000000     7200         4
# 266  908275110       1560     103500    70.000000    11767         4
# 274  908102110        992     155891    68.000000     8842         4
# 276  533350090       2944     150000    71.466667    24572         3
# 290  535325460       2039     167000   118.000000    21299         4
# 310  908154205       4676     184750   130.000000    40094         3
# 333  921128020       2018     378500    89.000000    13214         3
# 354  534128190       2640     256900    80.000000    10400         4
# 374  528178070       2649     421250   130.000000    16900         4
# 389  905427030       3672     415000    60.000000    19800         4
# 392  528116010       1782     296000   129.000000    16870         3
# 408  527214060       2698     535000    82.000000    16052         3
# 428  902207130        832      12789    68.000000     9656         4
# 445  528480060       2078     339750    85.000000    10800         4
# 470  902330010       2358     122000    50.000000     5250         4
# 486  533215080       1709     328900    50.000000     5119         3
# 488  532476050       2646     260000   100.000000    14330         3
# 513  528108020       2042     253293    98.000000    12704         4
# 537  923251180       1224     131000   160.000000    20000         4
# 539  527355150       2524     278000    80.000000     9600         4
# 579  921128050       1978     425000    85.000000    12633         3
# 585  528150070       2364     611657   100.000000    12919         3
# 607  527108070       1746     377500    42.000000    14892         3
# 614  535450180       1192     135000    60.000000    10800         4
# 616  527216080       2338     591587    52.000000    51974         3
# 618  527252070       1419     392000    60.000000     8089         4
# 628  528228360       1511     246990    46.866667     2938         4
# 630  527256040       2042     455000    81.000000    13870         3
# 647  902300110       1627     139500    69.000000     9142         4
# 662  535426130       2080     135000    70.000000    11606         3
# 678  902103120       1944     103500    57.000000    10307         4
# 684  916252170       1295     230000    69.287073     8239         3
# 688  528482090       2466     340000   102.000000    11143         3
# 718  528174080       1364     185850    43.000000     7052         3
# 730  528118040       2758     418000   118.000000    13654         3
# 741  911102170       1317      40000    50.000000     8500         4
# 756  908103260       1033     165000    64.000000    12102         4
# 775  907295100       1838     185000    83.000000    10126         4
# 782  533125120       2826     334000   105.000000    11025         4
# 794  905103060       1392     121500    75.388889    11341         3
# 803  527216070       3279     538000    47.000000    53504         2
# 818  528108130       2020     404000    95.000000    12350         4
# 820  909281030       1091     104000    79.000000     7801         3
# 845  527276040       1488     133000    73.362637    47280         3
# 871  528114050       1976     440000   110.000000    14977         3
# 891  527182190       1502     212000    60.666667     6820         3
# 907  921201060       1964     370000    85.000000    11447         3
# 998  534427010       1728      84900    98.000000    13260         3
# 8    528351010       4316     755000   104.000000    21535         3
# 41   533130130       2349     362500    85.000000    13143         3
# 113  528106020       2402     555000   105.000000    15431         4
# 116  923225260       2521     151400    42.000000     3964         4
# 145  528102140       2772     462000   110.000000    14257         4
# 147  528321010       2794     403000   174.000000    15138         3
# 179  528390100       2448     402000    52.000000    46589         2
# 180  906200230       1822     228500   104.000000    23920         4
# 213  528112040       1736     360000    95.000000    11578         4
# 221  533215030       1310     285000    62.959677     4538         3
# 236  527145090       1280     180000    39.000000     5070         3
# 268  905427010       2009     235000   114.000000    19950         4
# 279  533236060       1586     170000    24.000000     2645         4
# 282  533241030       1950     239000    66.000000     7399         3
# 311  527146135       2687     270000    68.000000    13108         3
# 326  528320060       3627     625000   118.000000    35760         3
# 380  909455060       1020     200000    35.000000     3907         3
# 395  909275250       1550     195000    66.000000    21780         4
# 412  527182020       1204     130000    30.000000     3701         3
# 418  527377030       1309     181000    78.000000    10140         4
# 515  528228295       1569     175900    51.000000     3635         4
# 534  532378120        864      62383    60.000000     8281         3
# 562  528326030       2198     250000    84.000000    14260         3
# 635  916125425       1786     228950    80.761905   164660         3
# 640  528110020       2674     610000   105.000000    13693         4
# 669  909475230       2726     315000    70.000000    18044         3
# 704  527225035       1752     164000   152.000000    12134         3
# 734  528344070       2475     355000    60.000000    17433         2
# 736  535125010       2207     180000    74.933718    19900         4
# 778  533352170       1479     130500    75.388889    13517         3
# 807  528188150       1626     154000    36.000000     2448         4
# 69   905376090       1325     216000    65.490066    17541         3
# 175  527184110       1321     212000    35.000000     5118         3
# 183  528365070       2646     260000    90.000000     9900         4
# 188  902400110       3608     475000    90.000000    22950         2
# 217  908130020        914     117250    75.000000     8050         4
# 224  526355170       2223     244000    95.000000    13651         3
# 272  528360050       3500     584500   114.000000    17242         3
# 281  924151050       2000     188000    74.000000     9627         4
# 297  924100040       1567     196000    74.412500     9819         3
# 312  528118090       2790     460000    96.000000    12539         4
# 334  909425010       1954     311500    70.756757    15660         3
# 352  902401120       2775     325000    75.000000    13500         4
# 363  909275110       1718     238000    60.000000     7230         4
# 375  534403100       1350     168500    82.000000     9020         4
# 383  533215070       1557     305000    35.000000     4109         3
# 394  917425190       1572     186700    50.000000    35133         4
# 421  533130020       1923     190000   107.000000    10186         3
# 466  535353180       2640     180000    94.000000    22136         4
# 473  533251110       2362     255000    80.000000    12000         4
# 478  905351045       1700     148400    89.764706     1700         4
# 495  916382100       2036     410000   113.000000    13438         3
# 505  527183060       1337     188500    65.000000     5950         3
# 552  527256120       2000     470000    90.000000    18261         3
# 556  531369020       1512     203000    76.000000    10141         3
# 568  905109130       2260     328000    80.000000    14000         4
# 610  528120160       1713     274900    76.000000     9591         4
# 612  905426030       1518     260000    85.000000    19550         4
# 644  527256030       2234     441929    85.000000    14082         3
# 680  528110010       2296     451950    97.000000    13478         3
# 681  528228325       1557     234000    46.866667     3196         4
# 697  904101070       3086     200500   138.000000    18030         3
# 722  905451330       1509     159900    68.000000     9571         4
#
#      Utilities  LandSlope  OverallQual  OverallCond  ...  SaleType_WD   \
# 30           3          1           10            5  ...          True
# 55           3          1            5            5  ...          True
# 57           3          1            8            5  ...         False
# 66           3          2           10            5  ...          True
# 74           3          2            8            5  ...         False
# 104          3          1            9            5  ...          True
# 109          3          1           10            5  ...         False
# 110          3          1            7            5  ...          True
# 112          3          1            8            5  ...          True
# 117          3          1            7            8  ...          True
# 125          3          1            9            5  ...          True
# 174          3          1            8            5  ...         False
# 181          3          1            7            5  ...          True
# 183          3          1            7            5  ...          True
# 203          3          1            7            5  ...         False
# 208          3          1            8            5  ...          True
# 217          3          1            9            5  ...          True
# 237          3          1            6            8  ...          True
# 247          3          2            8            5  ...          True
# 255          3          1            6            6  ...          True
# 266          3          1            5            5  ...          True
# 274          3          1            5            6  ...         False
# 276          3          1            9            3  ...          True
# 290          3          1            7            5  ...         False
# 310          3          1           10            5  ...         False
# 333          3          1            9            5  ...          True
# 354          3          1            6            7  ...          True
# 374          3          1            8            5  ...          True
# 389          3          1            6            8  ...          True
# 392          3          1            8            5  ...          True
# 408          3          1           10            5  ...         False
# 428          3          1            2            2  ...          True
# 445          3          1            8            5  ...         False
# 470          3          1            8            5  ...          True
# 486          3          1            9            5  ...         False
# 488          3          1            7            4  ...          True
# 513          3          1            8            5  ...         False
# 537          3          1            5            7  ...          True
# 539          3          1            8            5  ...          True
# 579          3          1            9            5  ...          True
# 585          3          1            9            5  ...         False
# 607          3          1            9            5  ...          True
# 614          3          1            4            4  ...          True
# 616          3          1            9            5  ...         False
# 618          3          1            8            6  ...         False
# 628          3          1            7            5  ...          True
# 630          3          1           10            5  ...         False
# 647          3          1            5            5  ...          True
# 662          3          3            5            5  ...          True
# 678          3          1            6            5  ...          True
# 684          3          1            7            5  ...          True
# 688          3          1            8            5  ...          True
# 718          3          1            7            5  ...          True
# 730          3          1            9            5  ...          True
# 741          3          1            4            4  ...          True
# 756          3          1            5            5  ...          True
# 775          3          1            6            5  ...          True
# 782          3          2            8            5  ...          True
# 794          3          1            5            6  ...          True
# 803          3          2            8            5  ...          True
# 818          3          1            9            5  ...          True
# 820          3          1            6            5  ...          True
# 845          3          1            6            5  ...          True
# 871          3          1            8            5  ...         False
# 891          3          1            8            5  ...          True
# 907          3          1            8            5  ...          True
# 998          3          1            5            6  ...         False
# 8            3          1           10            6  ...          True
# 41           3          1            8            5  ...          True
# 113          3          1           10            5  ...          True
# 116          3          1            6            4  ...          True
# 145          3          1            9            5  ...          True
# 147          3          1            8            5  ...          True
# 179          3          1            8            7  ...          True
# 180          3          1            6            5  ...          True
# 213          3          1            9            5  ...          True
# 221          3          1            9            5  ...          True
# 236          3          1            8            5  ...          True
# 268          3          1            6            7  ...          True
# 279          3          1            8            5  ...          True
# 282          3          1            7            5  ...          True
# 311          3          1            8            5  ...          True
# 326          3          1           10            5  ...          True
# 380          3          2            8            5  ...          True
# 395          3          1            6            5  ...          True
# 412          3          1            8            5  ...          True
# 418          3          1            6            6  ...          True
# 515          3          1            7            5  ...          True
# 534          3          1            5            5  ...          True
# 562          3          1            8            5  ...          True
# 635          3          3            5            6  ...          True
# 640          3          1           10            5  ...          True
# 669          3          1            8            5  ...          True
# 704          3          2            8            7  ...          True
# 734          3          1            8            5  ...          True
# 736          3          1            7            5  ...          True
# 778          3          1            6            8  ...          True
# 807          3          1            7            5  ...          True
# 69           3          1            5            7  ...          True
# 175          3          1            8            5  ...          True
# 183          3          2            7            5  ...          True
# 188          3          1           10            9  ...          True
# 217          3          1            6            5  ...          True
# 224          3          1            7            6  ...          True
# 272          3          1            9            5  ...          True
# 281          3          2            7            5  ...          True
# 297          3          2            6            5  ...          True
# 312          3          1           10            5  ...          True
# 334          3          1            7            9  ...          True
# 352          3          1           10            9  ...          True
# 363          3          1            7            7  ...          True
# 375          3          1            6            5  ...          True
# 383          3          1            9            5  ...          True
# 394          3          2            5            4  ...          True
# 421          3          1            7            5  ...          True
# 466          3          1            5            5  ...          True
# 473          3          1            7            6  ...          True
# 478          3          1            7            5  ...          True
# 495          3          1            9            5  ...          True
# 505          3          2            8            5  ...          True
# 552          3          1            9            5  ...          True
# 556          3          1            8            5  ...          True
# 568          3          2            7            5  ...          True
# 610          3          1            8            5  ...          True
# 612          3          1            5            7  ...          True
# 644          3          1            8            5  ...          True
# 680          3          1           10            5  ...         False
# 681          3          1            7            5  ...          True
# 697          3          1            5            6  ...          True
# 722          3          1            5            6  ...          True
#
#      Street_Grvl  Street_Pave  YrSold_2006  YrSold_2007  YrSold_2008  \
# 30         False         True        False         True        False
# 55         False         True        False        False        False
# 57         False         True        False         True        False
# 66         False         True        False        False         True
# 74         False         True        False        False         True
# 104        False         True        False        False        False
# 109        False         True        False         True        False
# 110        False         True        False         True        False
# 112        False         True        False        False        False
# 117        False         True        False         True        False
# 125        False         True        False        False         True
# 174        False         True         True        False        False
# 181        False         True        False        False        False
# 183        False         True        False         True        False
# 203        False         True         True        False        False
# 208        False         True        False        False         True
# 217        False         True        False        False         True
# 237        False         True        False         True        False
# 247        False         True        False         True        False
# 255        False         True        False         True        False
# 266        False         True        False        False        False
# 274        False         True        False        False        False
# 276        False         True        False        False         True
# 290        False         True         True        False        False
# 310        False         True        False         True        False
# 333        False         True        False        False        False
# 354        False         True        False        False        False
# 374        False         True        False        False         True
# 389        False         True         True        False        False
# 392        False         True        False        False        False
# 408        False         True         True        False        False
# 428        False         True        False        False        False
# 445        False         True        False        False         True
# 470        False         True        False        False         True
# 486        False         True        False        False         True
# 488        False         True         True        False        False
# 513        False         True        False        False        False
# 537        False         True         True        False        False
# 539        False         True        False        False        False
# 579        False         True        False        False        False
# 585        False         True        False        False        False
# 607        False         True        False        False        False
# 614        False         True         True        False        False
# 616        False         True        False         True        False
# 618        False         True        False         True        False
# 628        False         True         True        False        False
# 630        False         True        False         True        False
# 647        False         True        False        False         True
# 662        False         True        False         True        False
# 678        False         True        False        False        False
# 684        False         True         True        False        False
# 688        False         True        False         True        False
# 718        False         True         True        False        False
# 730        False         True        False         True        False
# 741        False         True        False        False         True
# 756        False         True        False        False         True
# 775        False         True        False        False         True
# 782        False         True         True        False        False
# 794        False         True        False        False        False
# 803        False         True        False        False        False
# 818        False         True        False        False        False
# 820        False         True        False        False         True
# 845        False         True        False        False         True
# 871        False         True        False         True        False
# 891        False         True        False        False        False
# 907        False         True        False        False         True
# 998        False         True        False        False        False
# 8          False         True        False         True        False
# 41         False         True        False        False        False
# 113        False         True        False        False        False
# 116        False         True         True        False        False
# 145        False         True        False        False        False
# 147        False         True        False        False        False
# 179        False         True        False        False        False
# 180        False         True        False         True        False
# 213        False         True        False        False        False
# 221        False         True        False        False         True
# 236        False         True        False        False         True
# 268        False         True         True        False        False
# 279        False         True        False        False         True
# 282        False         True        False         True        False
# 311        False         True         True        False        False
# 326        False         True         True        False        False
# 380        False         True        False         True        False
# 395        False         True         True        False        False
# 412        False         True         True        False        False
# 418        False         True         True        False        False
# 515        False         True        False        False        False
# 534        False         True        False        False        False
# 562        False         True        False        False         True
# 635         True        False        False        False         True
# 640        False         True        False        False        False
# 669        False         True        False         True        False
# 704        False         True        False        False        False
# 734        False         True        False        False        False
# 736        False         True        False        False        False
# 778        False         True        False        False        False
# 807        False         True        False        False         True
# 69         False         True        False         True        False
# 175        False         True        False         True        False
# 183        False         True        False        False        False
# 188        False         True         True        False        False
# 217        False         True         True        False        False
# 224        False         True        False         True        False
# 272        False         True         True        False        False
# 281        False         True         True        False        False
# 297        False         True        False        False        False
# 312        False         True        False        False         True
# 334        False         True        False        False         True
# 352        False         True        False        False         True
# 363        False         True        False         True        False
# 375        False         True        False        False         True
# 383        False         True        False        False         True
# 394         True        False        False         True        False
# 421        False         True        False        False        False
# 466        False         True         True        False        False
# 473        False         True        False         True        False
# 478        False         True         True        False        False
# 495        False         True        False        False        False
# 505        False         True        False        False         True
# 552        False         True         True        False        False
# 556        False         True        False        False        False
# 568        False         True        False        False        False
# 610        False         True        False        False        False
# 612        False         True        False        False         True
# 644        False         True        False         True        False
# 680        False         True        False        False        False
# 681        False         True         True        False        False
# 697        False         True        False         True        False
# 722        False         True        False        False         True
#
#      YrSold_2009  YrSold_2010  PredictedPrice      Residuals
# 30         False        False   402248.385403   47751.614597
# 55          True        False   138214.210950   40785.789050
# 57         False        False   329301.394509   65698.605491
# 66         False        False   564751.901549   50248.098451
# 74         False        False   295187.233777   97312.766223
# 104         True        False   394841.590888   73158.409112
# 109        False        False   454484.444195   45582.555805
# 110        False        False   198551.074895  131448.925105
# 112         True        False   219184.398101  -46684.398101
# 117        False        False   200583.886570  -41083.886570
# 125        False        False   386811.712238   88188.287762
# 174        False        False   371514.931468   51485.068532
# 181         True        False   176749.101336  -94249.101336
# 183        False        False   255972.658622  -48472.658622
# 203        False        False   212838.336660  -47848.336660
# 208        False        False   232098.506386  -52098.506386
# 217        False        False   245072.708902   44927.291098
# 237        False        False   227589.491957  -40089.491957
# 247        False        False   283329.342797  -48329.342797
# 255        False        False   198231.902527  -64331.902527
# 266         True        False   147239.013047  -43739.013047
# 274        False         True   101551.120389   54339.879611
# 276        False        False   317937.685908 -167937.685908
# 290        False        False   228542.617646  -61542.617646
# 310        False        False   549751.143529 -365001.143529
# 333        False         True   310280.302438   68219.697562
# 354         True        False   215862.226146   41037.773854
# 374        False        False   379488.375368   41761.624632
# 389        False        False   321637.696520   93362.303480
# 392         True        False   339649.362939  -43649.362939
# 408        False        False   441851.211785   93148.788215
# 428        False         True    58132.098462  -45343.098462
# 445        False        False   296839.438799   42910.561201
# 470        False        False   166264.455265  -44264.455265
# 486        False        False   266109.006354   62790.993646
# 488        False        False   300093.926066  -40093.926066
# 513         True        False   342724.578530  -89431.578530
# 537        False        False   181535.434645  -50535.434645
# 539         True        False   361885.042865  -83885.042865
# 579         True        False   349652.293521   75347.706479
# 585        False         True   466255.502776  145401.497224
# 607         True        False   322038.866288   55461.133712
# 614        False        False    83926.490689   51073.509311
# 616        False        False   451920.805933  139666.194067
# 618        False        False   302920.616656   89079.383344
# 628        False        False   204631.113373   42358.886627
# 630        False        False   393911.947689   61088.052311
# 647        False        False    98071.875622   41428.124378
# 662        False        False   193932.292281  -58932.292281
# 678         True        False   153273.402929  -49773.402929
# 684        False        False   149408.721613   80591.278387
# 688        False        False   268090.252554   71909.747446
# 718        False        False   237437.005757  -51587.005757
# 730        False        False   360882.815566   57117.184434
# 741        False        False    93379.318796  -53379.318796
# 756        False        False   121435.701401   43564.298599
# 775        False        False   233103.668520  -48103.668520
# 782        False        False   392596.209057  -58596.209057
# 794        False         True   169800.524602  -48300.524602
# 803        False         True   474004.227781   63995.772219
# 818         True        False   361534.455491   42465.544509
# 820        False        False   145771.164936  -41771.164936
# 845        False        False   176046.705903  -43046.705903
# 871        False        False   364375.965933   75624.034067
# 891        False         True   252393.085190  -40393.085190
# 907        False        False   315950.041563   54049.958437
# 998        False         True   177998.172507  -93098.172507
# 8          False        False   594656.443250  160343.556750
# 41         False         True   309139.555744   53360.444256
# 113         True        False   445744.519038  109255.480962
# 116        False        False   192881.485166  -41481.485166
# 145         True        False   418201.365277   43798.634723
# 147         True        False   345683.772471   57316.227529
# 179         True        False   361055.897417   40944.102583
# 180        False        False   170296.080205   58203.919795
# 213         True        False   302351.891616   57648.108384
# 221        False        False   240640.106290   44359.893710
# 236        False        False   224549.712341  -44549.712341
# 268        False        False   189050.805454   45949.194546
# 279        False        False   212373.032116  -42373.032116
# 282        False        False   297232.315290  -58232.315290
# 311        False        False   312218.585083  -42218.585083
# 326        False        False   489551.164626  135448.835374
# 380        False        False   155645.044173   44354.955827
# 395        False        False   149032.811646   45967.188354
# 412        False        False   183956.838198  -53956.838198
# 418        False        False   125324.509166   55675.490834
# 515         True        False   221567.322243  -45667.322243
# 534         True        False   116581.329060  -54198.329060
# 562        False        False   306313.280315  -56313.280315
# 635        False        False   277747.588146  -48797.588146
# 640         True        False   455683.612935  154316.387065
# 669        False        False   361577.351398  -46577.351398
# 704        False         True   214941.452665  -50941.452665
# 734        False         True   312587.758348   42412.241652
# 736        False         True   243135.873337  -63135.873337
# 778        False         True   184514.097881  -54014.097881
# 807        False        False   202674.539025  -48674.539025
# 69         False        False   146271.251332   69728.748668
# 175        False        False   255367.100981  -43367.100981
# 183         True        False   320621.339593  -60621.339593
# 188        False        False   403128.986061   71871.013939
# 217        False        False   157520.928568  -40270.928568
# 224        False        False   322891.992580  -78891.992580
# 272        False        False   456778.225130  127721.774870
# 281        False        False   229993.797584  -41993.797584
# 297         True        False   236455.688331  -40455.688331
# 312        False        False   417360.139843   42639.860157
# 334        False        False   243991.974030   67508.025970
# 352        False        False   283511.796529   41488.203471
# 363        False        False   189207.960842   48792.039158
# 375        False        False   218134.805830  -49634.805830
# 383        False        False   253514.974127   51485.025873
# 394        False        False   228871.102053  -42171.102053
# 421        False         True   249354.543600  -59354.543600
# 466        False        False   229807.581407  -49807.581407
# 473        False        False   308825.894327  -53825.894327
# 478        False        False   188642.755146  -40242.755146
# 495         True        False   354346.657110   55653.342890
# 505        False        False   237307.735117  -48807.735117
# 552        False        False   402552.611962   67447.388038
# 556         True        False   253231.630957  -50231.630957
# 568        False         True   268683.766551   59316.233449
# 610         True        False   326363.261529  -51463.261529
# 612        False        False   199850.915209   60149.084791
# 644        False        False   400573.774608   41355.225392
# 680         True        False   390447.210992   61502.789008
# 681        False        False   190898.339323   43101.660677
# 697        False        False   245706.881116  -45206.881116
# 722        False        False   201435.029678  -41535.029678
#
# [130 rows x 277 columns]
