# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import PredictionErrorDisplay
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SequentialFeatureSelector

# %%
ames = pd.read_csv('ames.csv', index_col=0)
ames.head(10)
# Out:
#           PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  \
# 1   909176150        856     126000          30       RL    58.769231
# 2   905476230       1049     139500         120       RL    42.000000
# 3   911128020       1001     124900          30  C (all)    60.000000
# 4   535377150       1039     114000          70       RL    80.000000
# 5   534177230       1665     227000          60       RL    70.000000
# 6   908128060       1922     198500          85       RL    64.000000
# 7   902135020        936      93000          20       RM    60.000000
# 8   528228540       1246     187687          20       RL    53.000000
# 9   923426010        889     137500          20       RL    74.000000
# 10  908186050       1072     140000         180       RM    35.000000
#
#     LotArea Street     Alley LotShape  ... SaleType SaleCondition TotalBath  \
# 1      7890   Pave  No Alley      Reg  ...      WD         Normal       2.0
# 2      4235   Pave  No Alley      Reg  ...      WD         Normal       3.0
# 3      6060   Pave  No Alley      Reg  ...      WD         Normal       1.0
# 4      8146   Pave  No Alley      Reg  ...      WD         Normal       1.0
# 5      8400   Pave  No Alley      Reg  ...      WD         Normal       3.5
# 6      7301   Pave  No Alley      Reg  ...    ConLD        Normal       3.0
# 7      6000   Pave      Pave      Reg  ...      WD         Normal       1.0
# 8      3710   Pave  No Alley      Reg  ...      New       Partial       2.0
# 9     12395   Pave  No Alley      Reg  ...      WD         Normal       1.0
# 10     3675   Pave  No Alley      Reg  ...      WD         Normal       2.0
#
#    TotalSF    HQSF yrsbtwn BedxBath RoomsxBath FireplaceYN  TotalPorchSF
# 1   1712.0  1712.0      11      4.0        8.0           1           166
# 2   2098.0  2098.0       0      6.0       15.0           0           105
# 3   1838.0  1838.0      77      2.0        5.0           0           282
# 4   1444.0  1444.0     103      2.0        6.0           0           279
# 5   2475.0  2475.0       0     10.5       21.0           0            45
# 6   1922.0  1922.0       0     12.0       21.0           1           177
# 7   1872.0  1872.0       0      2.0        4.0           0           144
# 8   2392.0  2392.0       1      4.0       10.0           1           124
# 9   1753.0  1753.0       0      3.0        6.0           0             0
# 10  1619.0  1619.0       0      4.0       10.0           0            44
#
# [10 rows x 89 columns]

# %% [markdown]
# ### SLR with Train-Test Split: Run a linear regression on every column vs SalePrice and Report R^2, beta, intercept

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
pd.set_option('display.max_rows', 100)

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

y = ames[['SalePrice']]
X = ames.drop(columns = ['PID', 'SalePrice'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0)

cat_cols = [i for i, col in enumerate(X_train.columns) if X_train[col].dtype == 'object']

encoder = OneHotEncoder(drop = 'first', handle_unknown = 'ignore')

results_list = []



for col in range(X_train.shape[1]):
    df_list = []
    
    if col in cat_cols:
        
        transformed_col = encoder.fit_transform(X_train.iloc[:, [col]])
    else:
        transformed_col = X_train.iloc[:, [col]]
    
    X_feature_train, X_feature_test, Y_train, Y_test = train_test_split(transformed_col, y_train, test_size = .2, random_state = 0)
    
    model = LinearRegression()
    model.fit(X_feature_train, Y_train)
    
    Y_pred = model.predict(X_feature_test)
    
    r2 = r2_score(Y_test, Y_pred)
    
    col_name = X_train.columns[col]
    
    df_list.append(col_name)
    
    df_list.append(r2)
    
    coef_flat = model.coef_.flatten().tolist()
    
    df_list.append(coef_flat)
    
    df_list.append(model.intercept_[0])

    results_list.append(df_list)

results_list = sorted(results_list, key=lambda x: x[1], reverse = True)

slr_detailed = pd.DataFrame(results_list, columns = ['feature', 'r2', 'betas', 'intercept'])

slr_detailed
# Out:
#           feature        r2  \
# 0            HQSF  0.701772
# 1         TotalSF  0.698450
# 2     OverallQual  0.602340
# 3    Neighborhood  0.548470
# 4       ExterQual  0.529352
# 5       GrLivArea  0.527104
# 6      RoomsxBath  0.480096
# 7     KitchenQual  0.468366
# 8        BsmtQual  0.447437
# 9     TotalBsmtSF  0.436160
# 10       1stFlrSF  0.432079
# 11      TotalBath  0.427916
# 12     GarageCars  0.365146
# 13     GarageArea  0.327094
# 14    FireplaceQu  0.293645
# 15     Fireplaces  0.290743
# 16      YearBuilt  0.288211
# 17       FullBath  0.276244
# 18     Foundation  0.272836
# 19    FireplaceYN  0.263465
# 20   TotRmsAbvGrd  0.263159
# 21     BsmtFinSF1  0.252166
# 22   YearRemodAdd  0.251061
# 23       BedxBath  0.247765
# 24   GarageFinish  0.246490
# 25     GarageType  0.235137
# 26     MasVnrArea  0.225350
# 27   BsmtFinType1  0.220456
# 28   BsmtExposure  0.187512
# 29      HeatingQC  0.164570
# 30   TotalPorchSF  0.163745
# 31     MasVnrType  0.137454
# 32    Exterior1st  0.132162
# 33     WoodDeckSF  0.124553
# 34    LotFrontage  0.122350
# 35   BsmtFullBath  0.116517
# 36       LotShape  0.114384
# 37    Exterior2nd  0.108342
# 38       HalfBath  0.096827
# 39       MSZoning  0.095351
# 40       SaleType  0.085840
# 41      RoofStyle  0.077775
# 42     PavedDrive  0.077261
# 43     GarageQual  0.075959
# 44        LotArea  0.071029
# 45     GarageCond  0.067323
# 46       2ndFlrSF  0.064002
# 47     Electrical  0.061779
# 48     HouseStyle  0.057359
# 49        yrsbtwn  0.055935
# 50     CentralAir  0.055306
# 51  SaleCondition  0.053365
# 52       BsmtCond  0.052070
# 53    GarageYrBlt  0.048812
# 54    OpenPorchSF  0.045612
# 55   BsmtFinType2  0.039089
# 56    LandContour  0.038293
# 57      ExterCond  0.032143
# 58       BldgType  0.032063
# 59     Condition1  0.029410
# 60          Fence  0.020126
# 61      LotConfig  0.018992
# 62    ScreenPorch  0.017844
# 63   BedroomAbvGr  0.017772
# 64          Alley  0.016565
# 65    OverallCond  0.010806
# 66      BsmtUnfSF  0.009912
# 67   KitchenAbvGr  0.008203
# 68      LandSlope  0.006988
# 69  EnclosedPorch  0.004710
# 70         Street  0.003437
# 71         PoolQC  0.002861
# 72     Functional  0.002837
# 73    MiscFeature  0.002044
# 74     MSSubClass  0.001820
# 75      Utilities  0.001253
# 76        Heating  0.000953
# 77   BsmtHalfBath -0.000930
# 78       PoolArea -0.000964
# 79     Condition2 -0.001091
# 48  [-37996.72173270286, 35219.08480360896, 126985...  1.405149e+05
# 49                               [-678.0970818776403]  1.856929e+05
# 50                                [78821.50418854342]  1.029660e+05
# 51  [-12424.378378338692, 39075.62162166132, -5962...  1.399244e+05
# 52  [-107073.58490908924, -28064.897064106517, -11...  2.250000e+05
# 53                                [44.45655911659676]  9.281888e+04
# 54                                [360.1292669580056]  1.597850e+05
# 55  [-9256.666666725878, 20145.833333306255, -1601...  1.772167e+05
# 56  [64687.74731182768, 45962.91666666645, 22895.6...  1.524558e+05
# 57  [-95238.57142869088, -44249.20786617928, -4810...  2.071000e+05
# 58  [-53905.55361809691, -35655.21510533331, -4427...  1.797291e+05
# 59  [10694.917418425908, 48058.865279790145, 11893...  1.313466e+05
# 60  [-25247.138554226538, -31465.87087749666, -522...  1.753596e+05
# 61  [35799.89837356617, 1425.1533725354666, 3526.9...  1.736821e+05
# 62                                [92.06289452623281]  1.751493e+05
# 63                               [13584.015432954033]  1.379149e+05
# 64             [52847.50639220822, 53124.84737678849]  1.258589e+05
# 65                               [-6563.462759888457]  2.135275e+05
# 66                                [32.41141814264369]  1.593078e+05
# 67                               [-36595.41401691079]  2.143948e+05
# 68             [15922.199379600332, 25616.1743404767]  1.757116e+05
# 69                              [-127.98109070114013]  1.794681e+05
# 70                                [42833.29523809477]  1.338583e+05
# 71  [25088.215138634863, 0.0, -13926.43027727394, ...  1.904118e+05
# 72  [-30075.628572324662, 9637.59919807564, 13492....  1.372964e+05
# 73  [21834.863895099887, -30833.333333357397, 1341...  1.555000e+05
# 74                              [-140.53872233864396]  1.846244e+05
# 75                               [-61573.26000000002]  1.765733e+05
# 76  [104703.43956041265, 89845.00001608432, 5625.0...  7.250000e+04
# 77                               [-9836.527000921707]  1.771318e+05
# 78                               [31.700747319094663]  1.764943e+05
# 79  [52823.43555345235, 340053.33333318384, 203094...  1.232800e+05
# 80                              [-37.160536484141396]  1.767085e+05
# 81                                 [5.19988011696552]  1.762532e+05
# 82                              [-2.9956913312973468]  1.766898e+05
# 83                               [-516.1989272302552]  1.212988e+06
# 84                                [881.4159361178772]  1.711225e+05
# 85  [0.0, -38541.95030674847, 12402.494137695976, ...  1.755420e+05
# 86                                [163.3278542726703]  1.762055e+05

# %% [markdown]
# ### 'Back of Envelope' Interpretation

# %%
slr_detailed.loc[0,:]
#By just plotting high quality square footage at a rate of $77.21/ft^2, you can explain about 70% of the saleprices.
#The intercept is a construct for the regression. (226 ft^2 before you're paying $0!)
# Out:
# feature                     HQSF
# r2                      0.701772
# betas        [77.21613680254939]
# intercept          -17459.359146
# Name: 0, dtype: object

# %%
slr_detailed.loc[2,:]
# Out:
# feature              OverallQual
# r2                       0.60234
# betas        [42212.01016287305]
# intercept          -78116.742715
# Name: 2, dtype: object

# %%
def numeric_slr_plot(myseries, df = ames):
    colname = myseries[0]
    R2 = myseries[1]
    m = myseries[2][0]
    b = myseries[3]
    
    mydf = df.loc[:, [colname, 'SalePrice']]
    sns.scatterplot(data = mydf, x = colname, y = 'SalePrice')
    x_vals = np.linspace(df[[colname]].min(), df[[colname]].max(), 100)
    y_vals = m*x_vals + b
    plt.plot(x_vals, y_vals, color='red', label= f'y= {m}x + {b}')
    plt.title(f"{colname} vs. Sale Price")
    plt.legend()
    plt.show()

#Plot numeric variables vs. SalePrice w/ regression line (try 0, 1, 2)
numeric_slr_plot(slr_detailed.loc[0,:], ames)
numeric_slr_plot(slr_detailed.loc[1,:], ames)
numeric_slr_plot(slr_detailed.loc[2,:], ames)

# %%
slr_detailed.loc[3, 'betas']
#df.loc[3, :]
#Neighborhood coefficients--- which of these are significant/have robust enough # of homes?
#We are talking about almost $200K difference here. Some of these neighborhoods only have 1 or 2 homes, and the
#p-values associated with each will certainly not be significant.
# Out:
# [-49594.61527449699,
#  -93844.61512463707,
#  -71144.97577890745,
#  9963.298008158705,
#  -4535.2038629650315,
#  2105.3859319617577,
#  -65968.19086601882,
#  -9985.172831017999,
#  -6844.615314050307,
#  81905.38464371194,
#  -90449.01934576307,
#  -61094.61537672886,
#  -97603.3107150738,
#  -37096.696599377894,
#  -53352.84143073371,
#  -55833.90090578082,
#  -5531.389287262127,
#  125547.43092849312,
#  108626.12736956871,
#  -72266.11711478647,
#  -65502.614950815376,
#  -58583.821069452584,
#  -7630.494550128224,
#  27248.985002569185,
#  111585.24206482976,
#  50720.567006123754,
#  53558.71815793986]

# %% [markdown]
# ### Cross-Validation:
# Run a linear regression on every column vs SalePrice and Report R^2.

# %%
from sklearn.model_selection import cross_val_score
pd.options.display.float_format = '{:.4f}'.format

y = ames[['SalePrice']]
X = ames.drop(columns = ['PID', 'SalePrice'])

cat_cols = [i for i, col in enumerate(X.columns) if X[col].dtype == 'object']

encoder = OneHotEncoder(drop = 'first', handle_unknown = 'ignore')

big_list = []

for col in range(X.shape[1]):
    
    if col in cat_cols:
        
        transformed_col = encoder.fit_transform(X.iloc[:, [col]])
    else:
        transformed_col = X.iloc[:, [col]]
    
    model = LinearRegression()
    
    col_name = X.columns[col]
    
    df_list = [col_name]
    
    cv_scores = cross_val_score(model, transformed_col, y, cv = 5)
    
    df_list.extend(cv_scores)
    
    df_list.extend([np.mean(cv_scores), np.std(cv_scores)])
    
    big_list.append(df_list)

big_list = sorted(big_list, key = lambda x: x[6], reverse = True)


slr_CV_df = pd.DataFrame(big_list, columns = ['Feature', 'Fold1', 'Fold2', 'Fold3', 'Fold4', 'Fold5', 'Avg', 'Std'])
    
slr_CV_df
# Out:
#           Feature   Fold1   Fold2   Fold3   Fold4   Fold5     Avg    Std
# 0            HQSF  0.6698  0.6822  0.7277  0.6595  0.6102  0.6699 0.0379
# 1         TotalSF  0.6628  0.6797  0.7244  0.6656  0.5969  0.6659 0.0410
# 2     OverallQual  0.6178  0.6425  0.6178  0.6094  0.6026  0.6180 0.0135
# 3    Neighborhood  0.5444  0.5741  0.5362  0.5419  0.5062  0.5406 0.0216
# 4       GrLivArea  0.4884  0.5412  0.5214  0.5458  0.4672  0.5128 0.0305
# 71    OverallCond  0.0101  0.0119 -0.0024 -0.0225 -0.0019 -0.0010 0.0123
# 72        Heating -0.0063  0.0008 -0.0035 -0.0083  0.0086 -0.0017 0.0060
# 73     MSSubClass  0.0005  0.0082  0.0023 -0.0214 -0.0061 -0.0033 0.0101
# 74      LandSlope  0.0092 -0.0013 -0.0113 -0.0328 -0.0022 -0.0077 0.0141
# 75    MiscFeature -0.0016 -0.0006 -0.0051 -0.0244 -0.0072 -0.0078 0.0086
# 76         Street -0.0031  0.0013 -0.0023 -0.0320 -0.0034 -0.0079 0.0122
# 77   BsmtHalfBath -0.0034 -0.0008 -0.0087 -0.0213 -0.0093 -0.0087 0.0071
# 78      3SsnPorch -0.0059 -0.0008 -0.0118 -0.0219 -0.0055 -0.0092 0.0073
# 79        MiscVal -0.0027 -0.0026 -0.0096 -0.0262 -0.0065 -0.0095 0.0087
# 80      Utilities -0.0034 -0.0026 -0.0096 -0.0251 -0.0075 -0.0097 0.0082
# 81       PoolArea -0.0014 -0.0018 -0.0105 -0.0250 -0.0102 -0.0098 0.0085
# 82         YrSold -0.0072 -0.0028 -0.0108 -0.0252 -0.0079 -0.0108 0.0077
# 83   LowQualFinSF -0.0012 -0.0011 -0.0086 -0.0395 -0.0043 -0.0109 0.0146
# 84         MoSold -0.0035 -0.0025 -0.0094 -0.0250 -0.0149 -0.0111 0.0083
# 85         PoolQC  0.0243 -0.0030 -0.0145 -0.0555 -0.0099 -0.0117 0.0257
# 86     BsmtFinSF2 -0.0041 -0.0096 -0.0083 -0.0270 -0.0100 -0.0118 0.0079

# %%
#Plot Results of Top Variables for R2 in box plot

slr_CV_toplot = slr_CV_df.iloc[:11,0:6]
slr_CV_toplot2 = slr_CV_df.iloc[11:21, 0:6]

df_long = slr_CV_toplot.melt(id_vars='Feature', var_name='Fold', value_name='R^2')
df_long2 = slr_CV_toplot2.melt(id_vars='Feature', var_name='Fold', value_name='R^2')

plt.figure(figsize=(15, 6))
sns.boxplot(x='Feature', y='R^2', data=df_long)
plt.title('Boxplot of R^2 Scores for Top Ten Features in SLR with Sale Price (5-Fold CV)')
plt.xlabel('Feature')
plt.ylabel('R^2')
plt.show()

plt.figure(figsize=(15, 6))
sns.boxplot(x='Feature', y='R^2', data=df_long2)
plt.title('Boxplot of R^2 Scores for Top Ten Features in SLR with Sale Price (5-Fold CV)')
plt.xlabel('Feature')
plt.ylabel('R^2')
plt.show()

# %% [markdown]
# # Multiple Linear Regression
# With some clear insight through simple linear regression, the next step is multiple linear regression. I want to combine ~5 of these variables and create a model that is reasonably accurate (R^2 > .73) while still remaining as interpretable as possible. Can't just combine the top 5 because of concerns about multicolinearity and whether every dummified column will be statistically significant. Could you stil explain the equation on the back of an envelope?

# %%
def my_mlr(subset_list, df, log = False):
    """ my_mlr function: Reports R^2's from 5-fold CV, Average and Std in a Dataframe
    
        subset_list: list of lists- each element is list of columns you want to include in MLR
        df: specify dataframe to use
        log: option to take log transformation of response variable
    """
    
    y = df['SalePrice']
    
    if log == True:
        y = np.log(df['SalePrice'])
        
    results_list = []

    for subset in subset_list:
        X = df[subset]

        cat_cols = [col for col in X.columns if X[col].dtype == 'object']

        if cat_cols:
            encoder = OneHotEncoder(drop='first', handle_unknown='ignore')
            transformed_X = encoder.fit_transform(X[cat_cols])
            transformed_X = pd.DataFrame(transformed_X.toarray(), columns=encoder.get_feature_names_out())
            transformed_X.reset_index(drop=True, inplace=True)  # Reset index
            X.reset_index(drop=True, inplace=True)  # Reset index for X as well
            X = pd.concat([X.drop(columns=cat_cols), transformed_X], axis=1)

        model = LinearRegression()
        cv_scores = cross_val_score(model, X, y, cv=5)

        df_list = [subset] + list(cv_scores) + [np.mean(cv_scores), np.std(cv_scores)]
        results_list.append(df_list)
        
        results_list = sorted(results_list, key = lambda x: x[6], reverse = True)

    CV_df = pd.DataFrame(results_list, columns=['Features'] + [f'Fold{i}' for i in range(1, 6)] + ['Avg', 'Std'])

    return CV_df

# %% [markdown]
# With my_mlr, you can run through a bunch of different combinations of variables, any length, and see what
# kind of model performance you get. This setup works right now if for categorical variables, every aspect
# plays a part. Another argument in the function is for the specified dataframe, so it's possible to experiment with multiple

# %%
ames.columns
# Out:
# Index(['PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'TotalBath', 'TotalSF', 'HQSF', 'yrsbtwn', 'BedxBath',
#        'RoomsxBath', 'FireplaceYN', 'TotalPorchSF'],
#       dtype='object')

# %%
#Suggestions from De Cock to improve performance of an MLR model- removes about 165 observations

ames_normal = ames[(ames['SaleCondition'] == 'Normal') & (ames['GrLivArea'] <= 4000)]

# %%
testlist = [
            ['HQSF', 'TotalBath', 'BedroomAbvGr', 'BedxBath',
             'GarageArea', 'BsmtQual', 'KitchenQual', 'ExterCond', 'FireplaceYN', 'MasVnrArea'], 
           
            ['GrLivArea', 'TotalBsmtSF', 'TotalBath', 'BedroomAbvGr', 'BedxBath',
             'GarageArea', 'BsmtQual', 'KitchenQual', 'ExterCond', 'FireplaceYN', 'MasVnrArea'],
           
            ['HQSF', 'GarageCars'],
    
            ['HQSF', 'OverallQual', 'TotalBath', 'BedroomAbvGr',
             'GarageArea', 'FireplaceYN'],
            
           
            ]

testlist1 = [
                ['HQSF', 'OverallQual', 'TotalBath', 'BedroomAbvGr', 'GarageArea', 'FireplaceYN'],
                ['HQSF', 'KitchenQual', 'BsmtQual', 'ExterCond', 'TotalBath', 'BedroomAbvGr', 'GarageArea', 'FireplaceYN']
            ]

#getting close here!

#my_mlr(testlist, ames_normal, log = False)
my_mlr(testlist1, ames_normal, log = True)
# Out:
#                                             Features  Fold1  Fold2  Fold3  \
# 0  [HQSF, OverallQual, TotalBath, BedroomAbvGr, G... 0.8718 0.8687 0.8536
# 1  [HQSF, KitchenQual, BsmtQual, ExterCond, Total... 0.8646 0.8490 0.8498
#
#    Fold4  Fold5    Avg    Std
# 0 0.8600 0.8455 0.8599 0.0097
# 1 0.8448 0.8345 0.8485 0.0097

# %%
def ols_results_1(X, y, features_list):
    for subset in features_list:
        X = X[subset]
                
        cat_cols = [col for col in X.columns if X[col].dtype == 'object']

        if cat_cols:
            print(cat_cols)
            encoder = OneHotEncoder(drop='first', handle_unknown='ignore')
            transformed_X = encoder.fit_transform(X[cat_cols])
            transformed_X = pd.DataFrame(transformed_X.toarray(), columns=encoder.get_feature_names_out())
            transformed_X.reset_index(drop=True, inplace=True)  # Reset index
            X.reset_index(drop=True, inplace=True)  # Reset index for X as well
            X = pd.concat([X.drop(columns=cat_cols), transformed_X], axis=1)
            print(X.columns)
        x = sm.add_constant(X.reset_index(drop=True))
        y = y.reset_index(drop=True)
        model= sm.OLS(y, x.loc[:, x.columns.values].astype(float))
        results = model.fit()
        print(results.summary())

# %%
ols_results_1(ames_normal, np.log(ames_normal['SalePrice']), [['HQSF', 'TotalBath', 'BedroomAbvGr',
             'GarageArea', 'BsmtQual', 'KitchenQual', 'ExterCond', 'FireplaceYN']])
ols_results_1(ames_normal, np.log(ames_normal['SalePrice']), [['HQSF', 'TotalBath', 'BedroomAbvGr',
             'GarageCars', 'OverallQual', 'FireplaceYN']])
# Out:
# ['BsmtQual', 'KitchenQual', 'ExterCond']
# Index(['HQSF', 'TotalBath', 'BedroomAbvGr', 'GarageArea', 'FireplaceYN',
#        'BsmtQual_Fa', 'BsmtQual_Gd', 'BsmtQual_No Bsmt', 'BsmtQual_Po',
#        'BsmtQual_TA', 'KitchenQual_Fa', 'KitchenQual_Gd', 'KitchenQual_Po',
#        'KitchenQual_TA', 'ExterCond_Fa', 'ExterCond_Gd', 'ExterCond_Po',
#        'ExterCond_TA'],
#       dtype='object')
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     774.0
# Date:                Wed, 05 Jun 2024   Prob (F-statistic):               0.00
# Time:                        14:49:34   Log-Likelihood:                 1286.9
# No. Observations:                2414   AIC:                            -2536.
# Df Residuals:                    2395   BIC:                            -2426.
# Df Model:                          18
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               11.5224      0.049    233.537      0.000      11.426      11.619
# HQSF                 0.0002   6.66e-06     34.073      0.000       0.000       0.000
# TotalBath            0.0614      0.005     11.861      0.000       0.051       0.072
# BedroomAbvGr        -0.0086      0.004     -2.021      0.043      -0.017      -0.000
# GarageArea           0.0003   1.82e-05     14.950      0.000       0.000       0.000
# FireplaceYN          0.0995      0.007     15.088      0.000       0.087       0.112
# BsmtQual_Fa         -0.2449      0.023    -10.471      0.000      -0.291      -0.199
# BsmtQual_Gd         -0.0800      0.015     -5.487      0.000      -0.109      -0.051
# BsmtQual_No Bsmt    -0.1730      0.025     -7.025      0.000      -0.221      -0.125
# BsmtQual_Po         -0.3067      0.102     -2.997      0.003      -0.507      -0.106
# BsmtQual_TA         -0.1671      0.016    -10.419      0.000      -0.199      -0.136
# KitchenQual_Fa      -0.3113      0.025    -12.221      0.000      -0.361      -0.261
# KitchenQual_Gd      -0.1018      0.016     -6.246      0.000      -0.134      -0.070
# KitchenQual_Po      -0.3202      0.144     -2.226      0.026      -0.602      -0.038
# KitchenQual_TA      -0.2100      0.017    -12.275      0.000      -0.244      -0.176
# ExterCond_Fa        -0.2781      0.048     -5.840      0.000      -0.371      -0.185
# ExterCond_Gd        -0.0569      0.044     -1.292      0.197      -0.143       0.030
# ExterCond_Po        -0.3666      0.110     -3.322      0.001      -0.583      -0.150
# ExterCond_TA        -0.0865      0.043     -1.993      0.046      -0.172      -0.001
# ==============================================================================
# Omnibus:                      314.002   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              958.600
# Skew:                          -0.669   Prob(JB):                    6.96e-209
# Kurtosis:                       5.782   Cond. No.                     1.31e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     2473.
# Date:                Wed, 05 Jun 2024   Prob (F-statistic):               0.00
# Time:                        14:49:34   Log-Likelihood:                 1347.0
# No. Observations:                2414   AIC:                            -2680.
# Df Residuals:                    2407   BIC:                            -2639.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.6335      0.016    655.963      0.000      10.602      10.665
# HQSF             0.0002   6.23e-06     32.339      0.000       0.000       0.000
# TotalBath        0.0714      0.005     15.065      0.000       0.062       0.081
# BedroomAbvGr    -0.0155      0.004     -3.924      0.000      -0.023      -0.008
# GarageCars       0.0708      0.005     14.104      0.000       0.061       0.081
# OverallQual      0.1000      0.003     32.512      0.000       0.094       0.106
# FireplaceYN      0.0649      0.006     10.034      0.000       0.052       0.078
# ==============================================================================
# Omnibus:                      318.239   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              806.129
# Skew:                          -0.735   Prob(JB):                    8.94e-176
# Kurtosis:                       5.419   Cond. No.                     1.52e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
    if log == True:
        y = np.log(df['SalePrice'])

# %%
#need to take this- try to manually run 5-Fold CV in here with a KFold object, that way we can report coefficients.
def mlr_coefs(subset, df, log = False):
    
    rmse_scores = []
    r2_scores = []
    coefs_per_fold = []
    
    all_y_pred = []
    all_y_actual = []
    residuals = []
    
    y = df['SalePrice']
    
    if log == True:
        y = np.log(df['SalePrice'])
    

    results_list = []

    X = df[subset]

    cat_cols = [col for col in X.columns if X[col].dtype == 'object']

    if cat_cols:
        encoder = OneHotEncoder(drop='first', handle_unknown='ignore')
        transformed_X = encoder.fit_transform(X[cat_cols])
        transformed_X = pd.DataFrame(transformed_X.toarray(), columns=encoder.get_feature_names_out())
        transformed_X.reset_index(drop=True, inplace=True)  # Reset index
        X.reset_index(drop=True, inplace=True)  # Reset index for X as well
        X = pd.concat([X.drop(columns=cat_cols), transformed_X], axis=1)
   
    kf = KFold(n_splits = 5, shuffle = False)
    
    for fold, (train_index, test_index) in enumerate(kf.split(X)):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]        
    
        lm = LinearRegression()
        lm.fit(X_train, y_train)
    
        coefs_per_fold.append(lm.coef_)
    
        y_pred = lm.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        rmse_scores.append(rmse)
        r2_scores.append(r2)
        
        all_y_pred.extend(y_pred)
        all_y_actual.extend(y_test.values)
        residuals.extend(y_test.values - y_pred)
        
        print(f"Fold {fold+1}: RMSE = {round(rmse, 4)}, R2 = {round(r2, 4)}")
    
    mean_rmse = np.mean(rmse_scores)
    mean_r2 = np.mean(r2_scores)
    print(f"Average RMSE: {round(mean_rmse, 4)}")
    print(f"Average R2: {round(mean_r2, 4)}")

# %%
mlr_coefs(['HQSF', 'OverallQual'], ames_normal)
# Out:
# Fold 1: RMSE = 32490.2028, R2 = 0.8073
# Fold 2: RMSE = 29252.2198, R2 = 0.8283
# Fold 3: RMSE = 30512.7584, R2 = 0.8041
# Fold 4: RMSE = 31710.9382, R2 = 0.7852
# Fold 5: RMSE = 31264.756, R2 = 0.783
# Average RMSE: 31046.175
# Average R2: 0.8016

# %%
top14 = slr_CV_df['Feature'][:14].tolist()
print(top14)
#Multicollinearity concerns- edit down to
top11 = ['HQSF', 'OverallQual', 'Neighborhood', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd']
# Out:
# ['HQSF', 'TotalSF', 'OverallQual', 'Neighborhood', 'GrLivArea', 'BsmtQual', 'ExterQual', 'RoomsxBath', 'KitchenQual', 'TotalBsmtSF', 'TotalBath', 'GarageCars', '1stFlrSF', 'GarageArea']

# %%
#pd.options.display.float_format = '{:.4f}'.format
from itertools import combinations

def my_mlr_1(cols, df):
    
    y = df['SalePrice']
    results_list = []

    
    X = df[cols]

    cat_cols = [col for col in X.columns if X[col].dtype == 'object']

    if cat_cols:
        encoder = OneHotEncoder(drop='first', handle_unknown='ignore')
        transformed_X = encoder.fit_transform(X[cat_cols])
        transformed_X = pd.DataFrame(transformed_X.toarray(), columns=encoder.get_feature_names_out())
        transformed_X.reset_index(drop=True, inplace=True)  # Reset index
        X.reset_index(drop=True, inplace=True)  # Reset index for X as well
        X = pd.concat([X.drop(columns=cat_cols), transformed_X], axis=1)

    model = LinearRegression()
    cv_scores = cross_val_score(model, X, y, cv=5)

    df_list = [cols] + list(cv_scores) + [np.mean(cv_scores), np.std(cv_scores)]
    results_list.append(df_list)

    results_list = sorted(results_list, key = lambda x: x[6], reverse = True)

    CV_df = pd.DataFrame(results_list, columns=['Features'] + [f'Fold{i}' for i in range(1, 6)] + ['Avg', 'Std'])

    return CV_df

pairs = combinations(top14, 2)
top14_pairings = [list(pair) for pair in pairs]
mlr_2_CV_df = my_mlr(top14_pairings, ames_normal)
mlr_2_CV_df
# Out:
#                        Features  Fold1  Fold2  Fold3  Fold4  Fold5    Avg  \
# 0           [HQSF, OverallQual] 0.8073 0.8283 0.8041 0.7852 0.7830 0.8016
# 1        [TotalSF, OverallQual] 0.8045 0.8292 0.8022 0.7879 0.7774 0.8003
# 2          [HQSF, Neighborhood] 0.8189 0.8375 0.8167 0.7695 0.7569 0.7999
# 3       [TotalSF, Neighborhood] 0.8163 0.8374 0.8159 0.7758 0.7517 0.7994
# 4             [HQSF, ExterQual] 0.8208 0.8127 0.7730 0.7486 0.7509 0.7812
# 5              [HQSF, BsmtQual] 0.8109 0.8101 0.8071 0.7450 0.7330 0.7812
# 6           [TotalSF, BsmtQual] 0.8064 0.8094 0.8052 0.7494 0.7264 0.7794
# 68     [TotalBsmtSF, TotalBath] 0.6440 0.6083 0.6116 0.5324 0.5794 0.5951
# 69      [BsmtQual, TotalBsmtSF] 0.6302 0.6344 0.5938 0.5353 0.5811 0.5950
# 70    [KitchenQual, GarageCars] 0.5969 0.6530 0.5247 0.5651 0.6078 0.5895
# 71     [RoomsxBath, GarageCars] 0.6109 0.6096 0.5563 0.5778 0.5841 0.5877
# 72      [ExterQual, GarageCars] 0.6199 0.6334 0.5261 0.5499 0.5980 0.5855
# 73    [KitchenQual, GarageArea] 0.5994 0.6346 0.5157 0.5812 0.5955 0.5853
# 74      [ExterQual, GarageArea] 0.6261 0.6147 0.5138 0.5749 0.5884 0.5836
# 75        [BsmtQual, TotalBath] 0.5936 0.5812 0.5675 0.5417 0.6087 0.5785
# 76       [BsmtQual, GarageArea] 0.5763 0.5931 0.5792 0.5711 0.5713 0.5782
# 77    [TotalBsmtSF, GarageCars] 0.6166 0.5767 0.5878 0.5391 0.5289 0.5698
# 78       [BsmtQual, GarageCars] 0.5724 0.5814 0.5699 0.5504 0.5692 0.5687
# 79      [GrLivArea, RoomsxBath] 0.5790 0.6126 0.5341 0.5922 0.4995 0.5635
# 80      [TotalBath, GarageArea] 0.5737 0.5713 0.5493 0.5621 0.5598 0.5633
# 81      [BsmtQual, KitchenQual] 0.5479 0.6366 0.5008 0.5234 0.6071 0.5632
# 82       [GarageCars, 1stFlrSF] 0.6079 0.5685 0.5556 0.5304 0.5386 0.5602
# 83        [BsmtQual, ExterQual] 0.5671 0.6166 0.4983 0.5091 0.5896 0.5561
# 84      [TotalBath, GarageCars] 0.5655 0.5609 0.5467 0.5296 0.5633 0.5532
# 85    [TotalBsmtSF, GarageArea] 0.6041 0.5459 0.5635 0.5411 0.4998 0.5509
# 86       [1stFlrSF, GarageArea] 0.5864 0.5325 0.5341 0.5301 0.5043 0.5375
# 87     [ExterQual, KitchenQual] 0.5389 0.5957 0.4366 0.4860 0.5526 0.5220
# 88      [RoomsxBath, TotalBath] 0.5074 0.5243 0.4260 0.4707 0.4819 0.4821
# 89      [TotalBsmtSF, 1stFlrSF] 0.5369 0.4506 0.4541 0.4353 0.3817 0.4517
# 90     [GarageCars, GarageArea] 0.4215 0.4343 0.4155 0.4041 0.4070 0.4165
#
#       Std
# 0  0.0166
# 1  0.0175
# 2  0.0311
# 3  0.0311
# 4  0.0304
# 5  0.0347
# 6  0.0347
# 7  0.0302
# 8  0.0262
# 9  0.0284
# 10 0.0257
# 11 0.0187
# 12 0.0305
# 13 0.0205
# 14 0.0316
# 15 0.0344
# 16 0.0183
# 17 0.0360
# 18 0.0234
# 19 0.0333
# 20 0.0348
# 21 0.0240
# 22 0.0331
# 23 0.0382
# 24 0.0411
# 25 0.0156
# 26 0.0261
# 27 0.0354
# 28 0.0307
# 29 0.0427
# 30 0.0432
# 31 0.0449
# 32 0.0453
# 33 0.0200
# 34 0.0243
# 35 0.0466
# 36 0.0466
# 37 0.0466
# 38 0.0478
# 39 0.0188
# 40 0.0194
# 41 0.0294
# 42 0.0417
# 43 0.0313
# 44 0.0266
# 45 0.0483
# 46 0.0273
# 47 0.0302
# 48 0.0355
# 49 0.0254
# 50 0.0192
# 51 0.0257
# 52 0.0285
# 53 0.0240
# 54 0.0444
# 55 0.0244
# 56 0.0258
# 57 0.0212
# 58 0.0351
# 59 0.0528
# 60 0.0410
# 61 0.0497
# 62 0.0445
# 63 0.0436
# 64 0.0305
# 65 0.0232
# 66 0.0414
# 67 0.0232
# 68 0.0375
# 69 0.0362
# 70 0.0429
# 71 0.0206
# 72 0.0411
# 73 0.0390
# 74 0.0394
# 75 0.0229
# 76 0.0080
# 77 0.0322
# 78 0.0101
# 79 0.0411
# 80 0.0087
# 81 0.0510
# 82 0.0273
# 83 0.0457
# 84 0.0135
# 85 0.0338
# 86 0.0268
# 87 0.0552
# 88 0.0338
# 89 0.0499
# 90 0.0109

# %%
top14_pairings
# Out:
# [['HQSF', 'TotalSF'],
#  ['HQSF', 'OverallQual'],
#  ['HQSF', 'Neighborhood'],
#  ['HQSF', 'GrLivArea'],
#  ['HQSF', 'BsmtQual'],
#  ['HQSF', 'ExterQual'],
#  ['HQSF', 'RoomsxBath'],
#  ['HQSF', 'KitchenQual'],
#  ['HQSF', 'TotalBsmtSF'],
#  ['HQSF', 'TotalBath'],
#  ['HQSF', 'GarageCars'],
#  ['HQSF', '1stFlrSF'],
#  ['HQSF', 'GarageArea'],
#  ['TotalSF', 'OverallQual'],
#  ['TotalSF', 'Neighborhood'],
#  ['TotalSF', 'GrLivArea'],
#  ['TotalSF', 'BsmtQual'],
#  ['TotalSF', 'ExterQual'],
#  ['TotalSF', 'RoomsxBath'],
#  ['TotalSF', 'KitchenQual'],
#  ['TotalSF', 'TotalBsmtSF'],
#  ['TotalSF', 'TotalBath'],
#  ['TotalSF', 'GarageCars'],
#  ['TotalSF', '1stFlrSF'],
#  ['TotalSF', 'GarageArea'],
#  ['OverallQual', 'Neighborhood'],
#  ['OverallQual', 'GrLivArea'],
#  ['OverallQual', 'BsmtQual'],
#  ['OverallQual', 'ExterQual'],
#  ['OverallQual', 'RoomsxBath'],
#  ['OverallQual', 'KitchenQual'],
#  ['OverallQual', 'TotalBsmtSF'],
#  ['OverallQual', 'TotalBath'],
#  ['OverallQual', 'GarageCars'],
#  ['OverallQual', '1stFlrSF'],
#  ['OverallQual', 'GarageArea'],
#  ['Neighborhood', 'GrLivArea'],
#  ['Neighborhood', 'BsmtQual'],
#  ['Neighborhood', 'ExterQual'],
#  ['Neighborhood', 'RoomsxBath'],
#  ['Neighborhood', 'KitchenQual'],
#  ['Neighborhood', 'TotalBsmtSF'],
#  ['Neighborhood', 'TotalBath'],
#  ['Neighborhood', 'GarageCars'],
#  ['Neighborhood', '1stFlrSF'],
#  ['Neighborhood', 'GarageArea'],
#  ['GrLivArea', 'BsmtQual'],
#  ['GrLivArea', 'ExterQual'],
#  ['GrLivArea', 'RoomsxBath'],
#  ['GrLivArea', 'KitchenQual'],
#  ['GrLivArea', 'TotalBsmtSF'],
#  ['GrLivArea', 'TotalBath'],
#  ['GrLivArea', 'GarageCars'],
#  ['GrLivArea', '1stFlrSF'],
#  ['GrLivArea', 'GarageArea'],
#  ['BsmtQual', 'ExterQual'],
#  ['BsmtQual', 'RoomsxBath'],
#  ['BsmtQual', 'KitchenQual'],
#  ['BsmtQual', 'TotalBsmtSF'],
#  ['BsmtQual', 'TotalBath'],
#  ['BsmtQual', 'GarageCars'],
#  ['BsmtQual', '1stFlrSF'],
#  ['BsmtQual', 'GarageArea'],
#  ['ExterQual', 'RoomsxBath'],
#  ['ExterQual', 'KitchenQual'],
#  ['ExterQual', 'TotalBsmtSF'],
#  ['ExterQual', 'TotalBath'],
#  ['ExterQual', 'GarageCars'],
#  ['ExterQual', '1stFlrSF'],
#  ['ExterQual', 'GarageArea'],
#  ['RoomsxBath', 'KitchenQual'],
#  ['RoomsxBath', 'TotalBsmtSF'],
#  ['RoomsxBath', 'TotalBath'],
#  ['RoomsxBath', 'GarageCars'],
#  ['RoomsxBath', '1stFlrSF'],
#  ['RoomsxBath', 'GarageArea'],
#  ['KitchenQual', 'TotalBsmtSF'],
#  ['KitchenQual', 'TotalBath'],
#  ['KitchenQual', 'GarageCars'],
#  ['KitchenQual', '1stFlrSF'],
#  ['KitchenQual', 'GarageArea'],
#  ['TotalBsmtSF', 'TotalBath'],
#  ['TotalBsmtSF', 'GarageCars'],
#  ['TotalBsmtSF', '1stFlrSF'],
#  ['TotalBsmtSF', 'GarageArea'],
#  ['TotalBath', 'GarageCars'],
#  ['TotalBath', '1stFlrSF'],
#  ['TotalBath', 'GarageArea'],
#  ['GarageCars', '1stFlrSF'],
#  ['GarageCars', 'GarageArea'],
#  ['1stFlrSF', 'GarageArea']]

# %%
def cvplot(df):
    toplot1 = df.iloc[:11, 0:6]
    toplot2 = df.iloc[11:21, 0:6]
    
    df_long = toplot1.melt(id_vars='Features', var_name='Fold', value_name='R^2')
    df_long2 = toplot2.melt(id_vars='Features', var_name='Fold', value_name='R^2')

    df_long['Features'] = df_long['Features'].apply(lambda x: ', '.join(map(str, x)))
    df_long2['Features'] = df_long2['Features'].apply(lambda x: ', '.join(map(str, x)))
    
    plt.figure(figsize=(15, 6))
    sns.boxplot(x='Features', y='R^2', data=df_long)
    plt.title('Boxplot of R^2 Scores for Top Ten Groupings in MLR with Sale Price (5-Fold CV)')
    plt.xlabel('Features')
    plt.ylabel('R^2')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()

    plt.figure(figsize=(15, 6))
    sns.boxplot(x='Features', y='R^2', data=df_long2)
    plt.title('Boxplot of R^2 Scores for Top Ten Groupings in MLR with Sale Price (5-Fold CV)')
    plt.xlabel('Features')
    plt.ylabel('R^2')
    plt.xticks(rotation=45)
    plt.show()

# %%
cvplot(mlr_2_CV_df)

# %%
for x in range(50):
    print(mlr_2_CV_df.iloc[x, 0])
# Out:
# ['HQSF', 'OverallQual']
# ['TotalSF', 'OverallQual']
# ['HQSF', 'Neighborhood']
# ['TotalSF', 'Neighborhood']
# ['HQSF', 'BsmtQual']
# ['TotalSF', 'BsmtQual']
# ['HQSF', 'ExterQual']
# ['TotalSF', 'ExterQual']
# ['HQSF', 'KitchenQual']
# ['TotalSF', 'KitchenQual']
# ['Neighborhood', 'GrLivArea']
# ['OverallQual', 'GrLivArea']
# ['OverallQual', '1stFlrSF']
# ['OverallQual', 'RoomsxBath']
# ['HQSF', 'GarageCars']
# ['TotalSF', 'GarageCars']
# ['GrLivArea', 'BsmtQual']
# ['HQSF', 'GarageArea']
# ['TotalSF', 'GarageArea']
# ['OverallQual', 'Neighborhood']
# ['GrLivArea', 'ExterQual']
# ['HQSF', 'TotalBath']
# ['TotalSF', 'TotalBath']
# ['OverallQual', 'TotalBsmtSF']
# ['OverallQual', 'TotalBath']
# ['HQSF', 'RoomsxBath']
# ['OverallQual', 'GarageArea']
# ['GrLivArea', 'KitchenQual']
# ['TotalSF', 'RoomsxBath']
# ['Neighborhood', 'RoomsxBath']
# ['Neighborhood', '1stFlrSF']
# ['OverallQual', 'BsmtQual']
# ['HQSF', 'TotalBsmtSF']
# ['HQSF', '1stFlrSF']
# ['HQSF', 'GrLivArea']
# ['HQSF', 'TotalSF']
# ['OverallQual', 'KitchenQual']
# ['OverallQual', 'GarageCars']
# ['TotalSF', '1stFlrSF']
# ['GrLivArea', 'TotalBsmtSF']
# ['TotalSF', 'GrLivArea']
# ['TotalSF', 'TotalBsmtSF']
# ['OverallQual', 'ExterQual']
# ['ExterQual', 'RoomsxBath']
# ['Neighborhood', 'TotalBsmtSF']
# ['Neighborhood', 'KitchenQual']
# ['RoomsxBath', 'KitchenQual']
# ['Neighborhood', 'ExterQual']
# ['Neighborhood', 'TotalBath']
# ['BsmtQual', 'RoomsxBath']

# %%
def mlr_coefs(subset, df):
    
    y = df['SalePrice']
    results_list = []

    X = df[subset]

    cat_cols = [col for col in X.columns if X[col].dtype == 'object']

    if cat_cols:
        encoder = OneHotEncoder(drop='first', handle_unknown='ignore')
        transformed_X = encoder.fit_transform(X[cat_cols])
        transformed_X = pd.DataFrame(transformed_X.toarray(), columns=encoder.get_feature_names_out())
        transformed_X.reset_index(drop=True, inplace=True)  # Reset index
        X.reset_index(drop=True, inplace=True)  # Reset index for X as well
        X = pd.concat([X.drop(columns=cat_cols), transformed_X], axis=1)
    
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = .2, random_state = 0)
    
    model = LinearRegression()
    model.fit(X_train, Y_train)
    
    Y_pred = model.predict(X_test)
    
    r2 = r2_score(Y_test, Y_pred)
    
    print(f'R2: {r2}')
    print(f' coefs: {model.coef_.flatten().tolist()}')
    print(f' intercept: {model.intercept_}')

# %%
for x in range(5):
    print(mlr_2_CV_df.iloc[x,0])
    mlr_coefs(mlr_2_CV_df.iloc[x, 0], ames)
# Out:
# ['HQSF', 'OverallQual']
# R2: 0.8010786074405741
#  coefs: [51.53028559099342, 23829.16600955244]
#  intercept: -95981.33483131166
# ['TotalSF', 'OverallQual']
# R2: 0.798250755665172
#  intercept: 216140.25980106235

# %% [markdown]
# ### Three Variables

# %%
trips = combinations(top14, 3)
top14_trips = [list(trip) for trip in trips]
mlr_3_CV_df = my_mlr(top14_trips, ames_normal)
mlr_3_CV_df
# Out:
#                                      Features  Fold1  Fold2  Fold3  Fold4  \
# 0           [HQSF, OverallQual, Neighborhood] 0.8404 0.8583 0.8478 0.8264
# 1        [TotalSF, OverallQual, Neighborhood] 0.8394 0.8588 0.8468 0.8309
# 2           [HQSF, Neighborhood, KitchenQual] 0.8384 0.8695 0.8403 0.8176
# 3        [TotalSF, Neighborhood, KitchenQual] 0.8362 0.8692 0.8397 0.8223
# 4               [HQSF, OverallQual, BsmtQual] 0.8409 0.8552 0.8400 0.8115
# 5            [TotalSF, OverallQual, BsmtQual] 0.8386 0.8555 0.8383 0.8145
# 6             [HQSF, Neighborhood, ExterQual] 0.8559 0.8683 0.8341 0.7920
# 7          [TotalSF, Neighborhood, ExterQual] 0.8539 0.8682 0.8332 0.7980
# 8            [HQSF, OverallQual, KitchenQual] 0.8321 0.8566 0.8176 0.8112
# 9              [HQSF, Neighborhood, BsmtQual] 0.8424 0.8552 0.8524 0.7917
# 10          [TotalSF, Neighborhood, BsmtQual] 0.8401 0.8552 0.8515 0.7966
# 11        [TotalSF, OverallQual, KitchenQual] 0.8291 0.8568 0.8163 0.8133
# 12             [HQSF, OverallQual, ExterQual] 0.8421 0.8529 0.8173 0.8004
# 13          [TotalSF, OverallQual, ExterQual] 0.8395 0.8533 0.8157 0.8039
# 14              [HQSF, BsmtQual, KitchenQual] 0.8288 0.8534 0.8153 0.7898
# 15                [HQSF, BsmtQual, ExterQual] 0.8458 0.8497 0.8174 0.7734
# 16     [OverallQual, Neighborhood, GrLivArea] 0.7890 0.8300 0.8192 0.8199
# 17            [HQSF, OverallQual, GarageArea] 0.8220 0.8287 0.8167 0.8062
# 18           [TotalSF, BsmtQual, KitchenQual] 0.8244 0.8527 0.8141 0.7931
# 19             [TotalSF, BsmtQual, ExterQual] 0.8422 0.8492 0.8155 0.7778
# 20         [TotalSF, OverallQual, GarageArea] 0.8196 0.8290 0.8149 0.8090
# 21             [HQSF, OverallQual, TotalBath] 0.8188 0.8283 0.8156 0.7985
# 22            [HQSF, OverallQual, GarageCars] 0.8203 0.8269 0.8138 0.8016
# 23           [HQSF, Neighborhood, GarageArea] 0.8265 0.8334 0.8319 0.7891
# 24          [TotalSF, OverallQual, TotalBath] 0.8165 0.8288 0.8139 0.8015
# 25         [TotalSF, OverallQual, GarageCars] 0.8179 0.8272 0.8120 0.8046
# 26        [TotalSF, Neighborhood, GarageArea] 0.8239 0.8331 0.8310 0.7945
# 27           [HQSF, Neighborhood, GarageCars] 0.8262 0.8313 0.8305 0.7858
# 28            [HQSF, OverallQual, RoomsxBath] 0.8132 0.8295 0.8085 0.7997
# 29        [TotalSF, Neighborhood, GarageCars] 0.8237 0.8310 0.8297 0.7914
# 30         [TotalSF, OverallQual, RoomsxBath] 0.8108 0.8299 0.8067 0.8021
# 31            [HQSF, Neighborhood, TotalBath] 0.8225 0.8366 0.8276 0.7811
# 32         [TotalSF, Neighborhood, TotalBath] 0.8199 0.8366 0.8267 0.7869
# 33           [HQSF, Neighborhood, RoomsxBath] 0.8209 0.8395 0.8204 0.7807
# 34        [TotalSF, Neighborhood, RoomsxBath] 0.8184 0.8393 0.8196 0.7859
# 35          [HQSF, Neighborhood, TotalBsmtSF] 0.8164 0.8365 0.8216 0.7782
# 36            [HQSF, Neighborhood, GrLivArea] 0.8161 0.8367 0.8213 0.7799
# 37              [HQSF, ExterQual, GarageCars] 0.8371 0.8280 0.7963 0.7733
# 38             [HQSF, ExterQual, KitchenQual] 0.8259 0.8416 0.7915 0.7758
# 39       [TotalSF, Neighborhood, TotalBsmtSF] 0.8136 0.8361 0.8205 0.7845
# 40     [Neighborhood, GrLivArea, TotalBsmtSF] 0.8136 0.8361 0.8205 0.7845
# 41         [TotalSF, Neighborhood, GrLivArea] 0.8136 0.8361 0.8205 0.7845
# 42           [HQSF, OverallQual, TotalBsmtSF] 0.8014 0.8255 0.8055 0.7891
# 43              [HQSF, OverallQual, 1stFlrSF] 0.8107 0.8233 0.8035 0.7878
# 44             [HQSF, OverallQual, GrLivArea] 0.8013 0.8257 0.8052 0.7892
# 45           [TotalSF, ExterQual, GarageCars] 0.8335 0.8273 0.7945 0.7778
# 46            [HQSF, KitchenQual, GarageCars] 0.8142 0.8292 0.7905 0.7910
# 47              [HQSF, ExterQual, GarageArea] 0.8396 0.8236 0.7937 0.7751
# 48        [Neighborhood, GrLivArea, BsmtQual] 0.7942 0.8324 0.8225 0.7900
# 49           [TotalSF, OverallQual, 1stFlrSF] 0.8083 0.8236 0.8016 0.7907
# 50      [OverallQual, GrLivArea, TotalBsmtSF] 0.7987 0.8258 0.8035 0.7914
# 51          [TotalSF, OverallQual, GrLivArea] 0.7987 0.8258 0.8035 0.7914
# 52        [TotalSF, OverallQual, TotalBsmtSF] 0.7987 0.8258 0.8035 0.7914
# 53               [HQSF, TotalSF, OverallQual] 0.8080 0.8231 0.8042 0.7830
# 54     [Neighborhood, GrLivArea, KitchenQual] 0.7873 0.8359 0.7990 0.8010
# 55          [TotalSF, ExterQual, KitchenQual] 0.8213 0.8408 0.7897 0.7797
# 56               [HQSF, ExterQual, TotalBath] 0.8374 0.8319 0.7915 0.7665
# 57           [TotalSF, ExterQual, GarageArea] 0.8358 0.8227 0.7917 0.7797
# 58             [HQSF, Neighborhood, 1stFlrSF] 0.8183 0.8312 0.8181 0.7697
# 59         [TotalSF, KitchenQual, GarageCars] 0.8096 0.8283 0.7890 0.7939
# 60       [Neighborhood, GrLivArea, ExterQual] 0.8101 0.8403 0.7864 0.7819
# 61          [TotalSF, Neighborhood, 1stFlrSF] 0.8157 0.8309 0.8173 0.7763
# 62            [HQSF, KitchenQual, GarageArea] 0.8149 0.8253 0.7892 0.7910
# 63               [HQSF, BsmtQual, GarageArea] 0.8266 0.8153 0.8257 0.7673
# 64            [TotalSF, ExterQual, TotalBath] 0.8338 0.8315 0.7895 0.7712
# 65              [HQSF, TotalSF, Neighborhood] 0.8169 0.8321 0.8181 0.7682
# 66            [TotalSF, BsmtQual, GarageArea] 0.8228 0.8145 0.8239 0.7713
# 67               [HQSF, BsmtQual, GarageCars] 0.8258 0.8123 0.8215 0.7655
# 68         [TotalSF, KitchenQual, GarageArea] 0.8100 0.8242 0.7875 0.7941
# 69         [OverallQual, GrLivArea, BsmtQual] 0.7773 0.8186 0.7996 0.7868
# 70            [TotalSF, BsmtQual, GarageCars] 0.8220 0.8115 0.8198 0.7696
# 71             [HQSF, KitchenQual, TotalBath] 0.8084 0.8338 0.7783 0.7841
# 72              [HQSF, ExterQual, RoomsxBath] 0.8306 0.8292 0.7812 0.7658
# 73        [OverallQual, RoomsxBath, 1stFlrSF] 0.7912 0.8088 0.7739 0.7958
# 74          [TotalSF, KitchenQual, TotalBath] 0.8035 0.8332 0.7764 0.7874
# 75           [TotalSF, ExterQual, RoomsxBath] 0.8267 0.8286 0.7789 0.7699
# 76         [OverallQual, GrLivArea, 1stFlrSF] 0.7801 0.8156 0.7852 0.7905
# 77                [HQSF, BsmtQual, TotalBath] 0.8211 0.8118 0.8139 0.7569
# 78             [TotalSF, BsmtQual, TotalBath] 0.8171 0.8111 0.8120 0.7612
# 79            [HQSF, RoomsxBath, KitchenQual] 0.7995 0.8311 0.7711 0.7792
# 80      [OverallQual, GrLivArea, KitchenQual] 0.7650 0.8235 0.7711 0.7801
# 81               [HQSF, BsmtQual, RoomsxBath] 0.8164 0.8160 0.8090 0.7531
# 82    [OverallQual, Neighborhood, RoomsxBath] 0.7554 0.8033 0.7786 0.8062
# 83             [HQSF, ExterQual, TotalBsmtSF] 0.8213 0.8258 0.7741 0.7572
# 84               [HQSF, GrLivArea, ExterQual] 0.8207 0.8256 0.7738 0.7576
# 85              [HQSF, BsmtQual, TotalBsmtSF] 0.8098 0.8170 0.8104 0.7511
# 86            [TotalSF, BsmtQual, RoomsxBath] 0.8124 0.8154 0.8070 0.7569
# 87                [HQSF, GrLivArea, BsmtQual] 0.8093 0.8170 0.8100 0.7516
# 88        [OverallQual, GrLivArea, ExterQual] 0.7815 0.8213 0.7637 0.7784
# 89         [TotalSF, RoomsxBath, KitchenQual] 0.7942 0.8304 0.7689 0.7818
# 90        [GrLivArea, ExterQual, TotalBsmtSF] 0.8163 0.8244 0.7717 0.7614
# 91            [TotalSF, GrLivArea, ExterQual] 0.8163 0.8244 0.7717 0.7614
# 92          [TotalSF, ExterQual, TotalBsmtSF] 0.8163 0.8244 0.7717 0.7614
# 93         [GrLivArea, BsmtQual, TotalBsmtSF] 0.8052 0.8159 0.8082 0.7548
# 94             [TotalSF, GrLivArea, BsmtQual] 0.8052 0.8159 0.8082 0.7548
# 95           [TotalSF, BsmtQual, TotalBsmtSF] 0.8052 0.8159 0.8082 0.7548
# 96                [HQSF, ExterQual, 1stFlrSF] 0.8223 0.8196 0.7737 0.7479
# 97                 [HQSF, BsmtQual, 1stFlrSF] 0.8108 0.8145 0.8092 0.7440
# 98      [OverallQual, Neighborhood, 1stFlrSF] 0.7726 0.7950 0.7757 0.7915
# 99        [Neighborhood, GrLivArea, 1stFlrSF] 0.7879 0.8161 0.7978 0.7752
# 100                [HQSF, TotalSF, ExterQual] 0.8223 0.8201 0.7740 0.7437
# 101                 [HQSF, TotalSF, BsmtQual] 0.8116 0.8136 0.8082 0.7418
# 102            [TotalSF, ExterQual, 1stFlrSF] 0.8178 0.8184 0.7714 0.7533
# 103             [TotalSF, BsmtQual, 1stFlrSF] 0.8062 0.8133 0.8071 0.7486
# 104    [OverallQual, RoomsxBath, TotalBsmtSF] 0.7939 0.7967 0.7696 0.7636
# 105          [HQSF, KitchenQual, TotalBsmtSF] 0.7851 0.8266 0.7682 0.7702
# 106            [HQSF, GrLivArea, KitchenQual] 0.7845 0.8262 0.7681 0.7701
# 107      [OverallQual, GrLivArea, GarageArea] 0.7550 0.7945 0.7702 0.7851
# 108             [HQSF, KitchenQual, 1stFlrSF] 0.7872 0.8223 0.7667 0.7620
# 109              [HQSF, TotalSF, KitchenQual] 0.7893 0.8219 0.7667 0.7590
# 110         [TotalSF, GrLivArea, KitchenQual] 0.7786 0.8249 0.7662 0.7726
# 111       [TotalSF, KitchenQual, TotalBsmtSF] 0.7786 0.8249 0.7662 0.7726
# 112     [GrLivArea, KitchenQual, TotalBsmtSF] 0.7786 0.8249 0.7662 0.7726
# 113          [GrLivArea, BsmtQual, ExterQual] 0.7920 0.8181 0.7578 0.7508
# 114        [OverallQual, TotalBath, 1stFlrSF] 0.7796 0.7795 0.7615 0.7661
# 115          [TotalSF, KitchenQual, 1stFlrSF] 0.7810 0.8208 0.7646 0.7659
# 116     [Neighborhood, GrLivArea, GarageArea] 0.7645 0.7959 0.7838 0.7698
# 117        [GrLivArea, BsmtQual, KitchenQual] 0.7649 0.8179 0.7580 0.7573
# 118      [OverallQual, GrLivArea, GarageCars] 0.7494 0.7882 0.7616 0.7729
# 119       [OverallQual, GrLivArea, TotalBath] 0.7457 0.7852 0.7600 0.7717
# 120     [Neighborhood, GrLivArea, GarageCars] 0.7630 0.7916 0.7799 0.7606
# 121           [GrLivArea, BsmtQual, 1stFlrSF] 0.7863 0.7946 0.7890 0.7494
# 122    [OverallQual, RoomsxBath, KitchenQual] 0.7617 0.7918 0.7250 0.7578
# 123      [Neighborhood, GrLivArea, TotalBath] 0.7541 0.7949 0.7723 0.7628
# 124      [Neighborhood, RoomsxBath, 1stFlrSF] 0.7639 0.7977 0.7650 0.7553
# 125      [OverallQual, GrLivArea, RoomsxBath] 0.7386 0.7835 0.7482 0.7658
# 126    [OverallQual, Neighborhood, TotalBath] 0.7208 0.7694 0.7719 0.7810
# 127         [GrLivArea, BsmtQual, GarageArea] 0.7660 0.7752 0.7766 0.7522
# 128          [GrLivArea, ExterQual, 1stFlrSF] 0.7947 0.8064 0.7318 0.7449
# 129       [OverallQual, BsmtQual, RoomsxBath] 0.7535 0.7735 0.7409 0.7525
# 130  [OverallQual, Neighborhood, TotalBsmtSF] 0.7532 0.7795 0.7589 0.7627
# 131     [OverallQual, RoomsxBath, GarageArea] 0.7512 0.7658 0.7351 0.7724
# 132      [OverallQual, ExterQual, RoomsxBath] 0.7692 0.7849 0.7234 0.7542
# 133   [Neighborhood, RoomsxBath, TotalBsmtSF] 0.7669 0.7946 0.7637 0.7278
# 134     [Neighborhood, GrLivArea, RoomsxBath] 0.7488 0.7929 0.7603 0.7544
# 135         [OverallQual, BsmtQual, 1stFlrSF] 0.7702 0.7672 0.7392 0.7399
# 136        [GrLivArea, ExterQual, GarageArea] 0.7826 0.7876 0.7183 0.7470
# 137         [GrLivArea, BsmtQual, GarageCars] 0.7611 0.7668 0.7652 0.7438
# 138             [HQSF, TotalBath, GarageCars] 0.7821 0.7604 0.7694 0.7380
# 139             [HQSF, TotalBath, GarageArea] 0.7830 0.7600 0.7690 0.7424
# 140        [GrLivArea, ExterQual, GarageCars] 0.7779 0.7912 0.7165 0.7353
# 141      [OverallQual, KitchenQual, 1stFlrSF] 0.7683 0.7769 0.7136 0.7443
# 142          [TotalSF, TotalBath, GarageCars] 0.7774 0.7594 0.7672 0.7425
# 143          [TotalSF, TotalBath, GarageArea] 0.7782 0.7589 0.7667 0.7469
# 144       [OverallQual, 1stFlrSF, GarageArea] 0.7612 0.7580 0.7284 0.7503
# 145        [OverallQual, ExterQual, 1stFlrSF] 0.7753 0.7729 0.7165 0.7343
# 146   [Neighborhood, RoomsxBath, KitchenQual] 0.7326 0.7939 0.7227 0.7569
# 147         [ExterQual, RoomsxBath, 1stFlrSF] 0.7841 0.7862 0.7106 0.7299
# 148   [OverallQual, Neighborhood, GarageArea] 0.7129 0.7561 0.7500 0.7801
# 149       [OverallQual, GarageCars, 1stFlrSF] 0.7620 0.7569 0.7244 0.7446
# 150     [OverallQual, TotalBsmtSF, TotalBath] 0.7653 0.7584 0.7466 0.7212
# 151     [OverallQual, RoomsxBath, GarageCars] 0.7414 0.7550 0.7238 0.7543
# 152     [Neighborhood, ExterQual, RoomsxBath] 0.7476 0.7916 0.7199 0.7370
# 153  [OverallQual, Neighborhood, KitchenQual] 0.7104 0.7694 0.7351 0.7698
# 154      [GrLivArea, KitchenQual, GarageArea] 0.7436 0.7861 0.7198 0.7485
# 155      [GrLivArea, KitchenQual, GarageCars] 0.7406 0.7886 0.7157 0.7396
# 156      [ExterQual, RoomsxBath, TotalBsmtSF] 0.7880 0.7773 0.7184 0.7020
# 157       [GrLivArea, ExterQual, KitchenQual] 0.7544 0.8019 0.7091 0.7322
# 158            [HQSF, RoomsxBath, GarageCars] 0.7725 0.7563 0.7560 0.7323
# 159         [GrLivArea, ExterQual, TotalBath] 0.7725 0.7895 0.6995 0.7315
# 160            [HQSF, RoomsxBath, GarageArea] 0.7724 0.7538 0.7543 0.7378
# 161   [OverallQual, Neighborhood, GarageCars] 0.7082 0.7490 0.7455 0.7645
# 162     [Neighborhood, KitchenQual, 1stFlrSF] 0.7392 0.7729 0.7213 0.7459
# 163         [TotalSF, RoomsxBath, GarageCars] 0.7675 0.7550 0.7536 0.7360
# 164       [Neighborhood, TotalBath, 1stFlrSF] 0.7405 0.7594 0.7552 0.7285
# 165        [GrLivArea, KitchenQual, 1stFlrSF] 0.7435 0.7995 0.7169 0.7462
# 166    [RoomsxBath, KitchenQual, TotalBsmtSF] 0.7651 0.7814 0.7018 0.7158
# 167     [OverallQual, Neighborhood, BsmtQual] 0.6984 0.7573 0.7507 0.7599
# 168         [TotalSF, RoomsxBath, GarageArea] 0.7672 0.7524 0.7516 0.7417
# 169      [Neighborhood, BsmtQual, RoomsxBath] 0.7248 0.7688 0.7372 0.7284
# 170            [HQSF, GarageCars, GarageArea] 0.7667 0.7498 0.7581 0.7221
# 171       [Neighborhood, ExterQual, 1stFlrSF] 0.7576 0.7720 0.7138 0.7107
# 172          [GrLivArea, BsmtQual, TotalBath] 0.7474 0.7582 0.7408 0.7256
# 173      [OverallQual, BsmtQual, TotalBsmtSF] 0.7562 0.7595 0.7192 0.7123
# 174           [HQSF, TotalBsmtSF, GarageCars] 0.7623 0.7516 0.7541 0.7217
# 175    [OverallQual, Neighborhood, ExterQual] 0.7186 0.7654 0.7262 0.7497
# 176             [HQSF, GrLivArea, GarageCars] 0.7619 0.7514 0.7540 0.7215
# 177              [HQSF, GarageCars, 1stFlrSF] 0.7650 0.7491 0.7559 0.7178
# 178               [HQSF, TotalSF, GarageCars] 0.7657 0.7491 0.7560 0.7143
# 179         [TotalSF, GarageCars, GarageArea] 0.7609 0.7481 0.7557 0.7266
# 180     [OverallQual, KitchenQual, TotalBath] 0.7316 0.7582 0.6994 0.7228
# 181          [BsmtQual, RoomsxBath, 1stFlrSF] 0.7630 0.7463 0.7311 0.7065
# 182          [TotalSF, GrLivArea, GarageCars] 0.7565 0.7495 0.7520 0.7253
# 183        [TotalSF, TotalBsmtSF, GarageCars] 0.7565 0.7495 0.7520 0.7253
# 184      [GrLivArea, TotalBsmtSF, GarageCars] 0.7565 0.7495 0.7520 0.7253
# 185        [Neighborhood, BsmtQual, 1stFlrSF] 0.7394 0.7506 0.7407 0.7142
# 186           [TotalSF, GarageCars, 1stFlrSF] 0.7593 0.7473 0.7535 0.7225
# 187           [HQSF, TotalBsmtSF, GarageArea] 0.7590 0.7464 0.7511 0.7250
# 188       [RoomsxBath, KitchenQual, 1stFlrSF] 0.7520 0.7801 0.6823 0.7338
# 189             [HQSF, GrLivArea, GarageArea] 0.7585 0.7460 0.7509 0.7247
# 190      [OverallQual, TotalBath, GarageArea] 0.7231 0.7325 0.7188 0.7396
# 191    [OverallQual, TotalBsmtSF, GarageArea] 0.7506 0.7425 0.7172 0.7276
# 192      [OverallQual, RoomsxBath, TotalBath] 0.7170 0.7457 0.7049 0.7300
# 193              [HQSF, 1stFlrSF, GarageArea] 0.7623 0.7433 0.7527 0.7192
# 194       [GrLivArea, KitchenQual, TotalBath] 0.7257 0.7880 0.6847 0.7362
# 195      [OverallQual, TotalBsmtSF, 1stFlrSF] 0.7485 0.7437 0.7083 0.7200
# 196               [HQSF, TotalSF, GarageArea] 0.7636 0.7427 0.7527 0.7153
# 197         [GrLivArea, BsmtQual, RoomsxBath] 0.7372 0.7615 0.7339 0.7135
# 198   [OverallQual, KitchenQual, TotalBsmtSF] 0.7506 0.7625 0.6966 0.7066
# 199        [TotalSF, TotalBsmtSF, GarageArea] 0.7527 0.7439 0.7486 0.7286
# 200          [TotalSF, GrLivArea, GarageArea] 0.7527 0.7439 0.7486 0.7286
# 201      [GrLivArea, TotalBsmtSF, GarageArea] 0.7527 0.7439 0.7486 0.7286
# 202        [GrLivArea, ExterQual, RoomsxBath] 0.7580 0.7794 0.6797 0.7175
# 203        [OverallQual, BsmtQual, TotalBath] 0.7205 0.7302 0.7198 0.7175
# 204    [OverallQual, TotalBsmtSF, GarageCars] 0.7494 0.7400 0.7149 0.7179
# 205           [TotalSF, 1stFlrSF, GarageArea] 0.7560 0.7412 0.7500 0.7242
# 206  [Neighborhood, KitchenQual, TotalBsmtSF] 0.7184 0.7667 0.7074 0.7197
# 207    [Neighborhood, RoomsxBath, GarageArea] 0.7105 0.7509 0.7206 0.7307
# 208       [BsmtQual, RoomsxBath, TotalBsmtSF] 0.7607 0.7477 0.7274 0.6727
# 209               [HQSF, TotalBath, 1stFlrSF] 0.7592 0.7454 0.7390 0.7067
# 210       [OverallQual, ExterQual, TotalBath] 0.7407 0.7507 0.7010 0.7113
# 211             [HQSF, RoomsxBath, TotalBath] 0.7590 0.7446 0.7415 0.6998
# 212          [ExterQual, TotalBath, 1stFlrSF] 0.7651 0.7507 0.6901 0.6865
# 213                [HQSF, TotalSF, TotalBath] 0.7576 0.7461 0.7382 0.6988
# 214            [HQSF, TotalBsmtSF, TotalBath] 0.7550 0.7464 0.7362 0.7025
# 215              [HQSF, GrLivArea, TotalBath] 0.7549 0.7462 0.7363 0.7010
# 216            [TotalSF, TotalBath, 1stFlrSF] 0.7537 0.7438 0.7364 0.7118
# 217    [Neighborhood, TotalBsmtSF, TotalBath] 0.7221 0.7451 0.7444 0.6882
# 218          [TotalSF, RoomsxBath, TotalBath] 0.7529 0.7430 0.7394 0.7055
# 219     [OverallQual, ExterQual, TotalBsmtSF] 0.7546 0.7530 0.6957 0.6921
# 220    [OverallQual, KitchenQual, GarageArea] 0.7210 0.7426 0.6831 0.7226
# 221       [GrLivArea, TotalBsmtSF, TotalBath] 0.7493 0.7445 0.7340 0.7061
# 222           [TotalSF, GrLivArea, TotalBath] 0.7493 0.7445 0.7340 0.7061
# 223         [TotalSF, TotalBsmtSF, TotalBath] 0.7493 0.7445 0.7340 0.7061
# 224      [OverallQual, TotalBath, GarageCars] 0.7131 0.7191 0.7087 0.7200
# 225    [Neighborhood, RoomsxBath, GarageCars] 0.7055 0.7407 0.7145 0.7143
# 226    [Neighborhood, KitchenQual, TotalBath] 0.6868 0.7550 0.6963 0.7314
# 227      [Neighborhood, 1stFlrSF, GarageArea] 0.7214 0.7260 0.7228 0.7115
# 228      [Neighborhood, GarageCars, 1stFlrSF] 0.7256 0.7240 0.7213 0.7061
# 229       [OverallQual, BsmtQual, GarageArea] 0.7098 0.7268 0.7022 0.7186
# 230       [ExterQual, RoomsxBath, GarageArea] 0.7549 0.7365 0.6602 0.7073
# 231    [Neighborhood, ExterQual, TotalBsmtSF] 0.7330 0.7584 0.6964 0.6779
# 232    [OverallQual, KitchenQual, GarageCars] 0.7135 0.7382 0.6746 0.7066
# 233      [GrLivArea, RoomsxBath, KitchenQual] 0.7063 0.7782 0.6679 0.7146
# 234      [Neighborhood, ExterQual, TotalBath] 0.7019 0.7533 0.7015 0.6997
# 235     [RoomsxBath, KitchenQual, GarageArea] 0.7327 0.7401 0.6512 0.7126
# 236        [KitchenQual, TotalBath, 1stFlrSF] 0.7334 0.7457 0.6565 0.7012
# 237         [BsmtQual, ExterQual, RoomsxBath] 0.7388 0.7455 0.6632 0.6732
# 238              [HQSF, RoomsxBath, 1stFlrSF] 0.7423 0.7397 0.7162 0.6991
# 239   [Neighborhood, KitchenQual, GarageArea] 0.6793 0.7297 0.6880 0.7283
# 240      [OverallQual, ExterQual, GarageArea] 0.7224 0.7316 0.6757 0.7136
# 241       [ExterQual, RoomsxBath, GarageCars] 0.7442 0.7347 0.6544 0.6871
# 242   [Neighborhood, TotalBsmtSF, GarageArea] 0.7108 0.7213 0.7177 0.6975
# 243           [HQSF, RoomsxBath, TotalBsmtSF] 0.7410 0.7383 0.7168 0.6901
# 244               [HQSF, TotalSF, RoomsxBath] 0.7412 0.7394 0.7166 0.6885
# 245             [HQSF, GrLivArea, RoomsxBath] 0.7416 0.7380 0.7172 0.6874
# 246       [BsmtQual, RoomsxBath, KitchenQual] 0.7202 0.7495 0.6503 0.6788
# 247       [OverallQual, BsmtQual, GarageCars] 0.7027 0.7157 0.6912 0.7023
# 248           [TotalSF, RoomsxBath, 1stFlrSF] 0.7363 0.7380 0.7128 0.7037
# 249   [Neighborhood, TotalBsmtSF, GarageCars] 0.7118 0.7182 0.7196 0.6892
# 250     [Neighborhood, BsmtQual, TotalBsmtSF] 0.7096 0.7333 0.7153 0.6726
# 251     [RoomsxBath, KitchenQual, GarageCars] 0.7223 0.7372 0.6430 0.6953
# 252          [TotalSF, GrLivArea, RoomsxBath] 0.7353 0.7361 0.7141 0.6924
# 253        [TotalSF, RoomsxBath, TotalBsmtSF] 0.7353 0.7361 0.7141 0.6924
# 254      [GrLivArea, RoomsxBath, TotalBsmtSF] 0.7353 0.7361 0.7141 0.6924
# 255       [ExterQual, TotalBsmtSF, TotalBath] 0.7482 0.7326 0.6801 0.6406
# 256   [Neighborhood, KitchenQual, GarageCars] 0.6745 0.7259 0.6851 0.7115
# 257     [KitchenQual, TotalBsmtSF, TotalBath] 0.7244 0.7388 0.6573 0.6657
# 258      [OverallQual, ExterQual, GarageCars] 0.7161 0.7289 0.6694 0.6936
# 259           [BsmtQual, TotalBath, 1stFlrSF] 0.7339 0.6897 0.7024 0.6632
# 260       [Neighborhood, BsmtQual, TotalBath] 0.6726 0.7113 0.7180 0.6986
# 261      [ExterQual, RoomsxBath, KitchenQual] 0.7249 0.7528 0.6326 0.6770
# 262     [Neighborhood, TotalBsmtSF, 1stFlrSF] 0.7171 0.7189 0.6920 0.6825
# 263     [Neighborhood, TotalBath, GarageArea] 0.6655 0.7088 0.7132 0.7018
# 264        [BsmtQual, RoomsxBath, GarageArea] 0.7199 0.6958 0.6835 0.6860
# 265           [BsmtQual, ExterQual, 1stFlrSF] 0.7362 0.7199 0.6586 0.6508
# 266     [RoomsxBath, TotalBsmtSF, GarageCars] 0.7354 0.6942 0.6978 0.6673
# 267     [RoomsxBath, TotalBsmtSF, GarageArea] 0.7375 0.6940 0.6957 0.6765
# 268     [Neighborhood, ExterQual, GarageArea] 0.6900 0.7225 0.6708 0.6991
# 269      [OverallQual, BsmtQual, KitchenQual] 0.6866 0.7247 0.6604 0.6721
# 270         [BsmtQual, KitchenQual, 1stFlrSF] 0.7126 0.7193 0.6472 0.6688
# 271         [ExterQual, GarageCars, 1stFlrSF] 0.7409 0.7117 0.6437 0.6549
# 272             [HQSF, TotalBsmtSF, 1stFlrSF] 0.7235 0.7280 0.7093 0.6771
# 273                [HQSF, TotalSF, GrLivArea] 0.7237 0.7283 0.7103 0.6708
# 274              [HQSF, TotalSF, TotalBsmtSF] 0.7237 0.7283 0.7103 0.6708
# 275            [HQSF, GrLivArea, TotalBsmtSF] 0.7237 0.7283 0.7103 0.6708
# 276               [HQSF, GrLivArea, 1stFlrSF] 0.7230 0.7275 0.7093 0.6757
# 277     [Neighborhood, ExterQual, GarageCars] 0.6867 0.7221 0.6744 0.6775
# 278      [Neighborhood, BsmtQual, GarageArea] 0.6596 0.7054 0.7074 0.7013
# 279     [Neighborhood, RoomsxBath, TotalBath] 0.6718 0.7313 0.6754 0.6848
# 280                 [HQSF, TotalSF, 1stFlrSF] 0.7284 0.7245 0.7123 0.6643
# 281         [GrLivArea, GarageCars, 1stFlrSF] 0.7093 0.7136 0.6921 0.6832
# 282     [Neighborhood, TotalBath, GarageCars] 0.6607 0.6962 0.7100 0.6827
# 283     [Neighborhood, BsmtQual, KitchenQual] 0.6470 0.7309 0.6681 0.6967
# 284         [TotalSF, GrLivArea, TotalBsmtSF] 0.7147 0.7261 0.7069 0.6805
# 285            [TotalSF, GrLivArea, 1stFlrSF] 0.7154 0.7247 0.7064 0.6816
# 286          [TotalSF, TotalBsmtSF, 1stFlrSF] 0.7154 0.7247 0.7064 0.6816
# 287        [GrLivArea, TotalBsmtSF, 1stFlrSF] 0.7154 0.7247 0.7064 0.6816
# 288        [BsmtQual, RoomsxBath, GarageCars] 0.7103 0.6807 0.6682 0.6676
# 289         [ExterQual, 1stFlrSF, GarageArea] 0.7400 0.6961 0.6318 0.6579
# 290        [OverallQual, BsmtQual, ExterQual] 0.6856 0.7156 0.6582 0.6665
# 291     [OverallQual, GarageCars, GarageArea] 0.6737 0.6929 0.6654 0.6931
# 292    [KitchenQual, TotalBsmtSF, GarageCars] 0.7069 0.7092 0.6376 0.6655
# 293      [Neighborhood, BsmtQual, GarageCars] 0.6573 0.6930 0.7021 0.6880
# 294         [GrLivArea, 1stFlrSF, GarageArea] 0.7007 0.7052 0.6892 0.6894
# 295          [GrLivArea, TotalBath, 1stFlrSF] 0.7055 0.7117 0.6783 0.6894
# 296       [KitchenQual, GarageCars, 1stFlrSF] 0.7133 0.7082 0.6249 0.6688
# 297          [BsmtQual, GarageCars, 1stFlrSF] 0.7102 0.6704 0.6842 0.6546
# 298      [KitchenQual, TotalBath, GarageArea] 0.6967 0.7071 0.6183 0.6786
# 299          [BsmtQual, 1stFlrSF, GarageArea] 0.7062 0.6714 0.6868 0.6543
# 300        [RoomsxBath, GarageCars, 1stFlrSF] 0.7095 0.6882 0.6646 0.6715
# 301      [ExterQual, TotalBsmtSF, GarageCars] 0.7233 0.7011 0.6464 0.6391
# 302        [BsmtQual, TotalBsmtSF, TotalBath] 0.7149 0.6827 0.6885 0.6167
# 303        [GrLivArea, TotalBath, GarageArea] 0.6855 0.6911 0.6653 0.6965
# 304        [ExterQual, TotalBath, GarageArea] 0.7171 0.6999 0.6318 0.6614
# 305        [RoomsxBath, 1stFlrSF, GarageArea] 0.7073 0.6858 0.6638 0.6809
# 306       [Neighborhood, BsmtQual, ExterQual] 0.6591 0.7233 0.6612 0.6677
# 307     [OverallQual, ExterQual, KitchenQual] 0.6797 0.7142 0.6403 0.6574
# 308      [KitchenQual, TotalBath, GarageCars] 0.6864 0.7025 0.6122 0.6613
# 309    [KitchenQual, TotalBsmtSF, GarageArea] 0.7059 0.6947 0.6250 0.6656
# 310    [Neighborhood, ExterQual, KitchenQual] 0.6532 0.7206 0.6418 0.6810
# 311      [ExterQual, TotalBsmtSF, GarageArea] 0.7258 0.6863 0.6316 0.6445
# 312        [GrLivArea, TotalBath, GarageCars] 0.6812 0.6854 0.6590 0.6769
# 313       [KitchenQual, 1stFlrSF, GarageArea] 0.7081 0.6916 0.6142 0.6668
# 314        [ExterQual, TotalBath, GarageCars] 0.7066 0.6972 0.6290 0.6400
# 315      [BsmtQual, KitchenQual, TotalBsmtSF] 0.6855 0.7144 0.6251 0.6282
# 316        [ExterQual, KitchenQual, 1stFlrSF] 0.7135 0.7024 0.6007 0.6415
# 317        [ExterQual, RoomsxBath, TotalBath] 0.7028 0.7137 0.5962 0.6383
# 318         [TotalBath, GarageCars, 1stFlrSF] 0.6941 0.6522 0.6621 0.6377
# 319        [BsmtQual, ExterQual, TotalBsmtSF] 0.6977 0.7022 0.6270 0.6024
# 320         [TotalBath, 1stFlrSF, GarageArea] 0.6907 0.6506 0.6601 0.6440
# 321       [BsmtQual, TotalBsmtSF, GarageCars] 0.6936 0.6650 0.6663 0.6165
# 322       [BsmtQual, TotalBsmtSF, GarageArea] 0.6899 0.6662 0.6665 0.6216
# 323      [TotalBsmtSF, TotalBath, GarageCars] 0.6969 0.6472 0.6782 0.6178
# 324       [RoomsxBath, TotalBsmtSF, 1stFlrSF] 0.7023 0.6810 0.6526 0.6360
# 325      [TotalBsmtSF, TotalBath, GarageArea] 0.6978 0.6474 0.6731 0.6258
# 326          [BsmtQual, ExterQual, TotalBath] 0.6861 0.6841 0.6187 0.6170
# 327        [BsmtQual, KitchenQual, TotalBath] 0.6670 0.6903 0.5958 0.6286
# 328       [GrLivArea, RoomsxBath, GarageArea] 0.6656 0.6755 0.6382 0.6777
# 329         [BsmtQual, TotalBath, GarageArea] 0.6721 0.6379 0.6510 0.6431
# 330       [ExterQual, KitchenQual, TotalBath] 0.6780 0.7092 0.5896 0.6248
# 331         [GrLivArea, RoomsxBath, 1stFlrSF] 0.6796 0.7004 0.6424 0.6694
# 332       [BsmtQual, KitchenQual, GarageArea] 0.6551 0.6757 0.6029 0.6420
# 333      [RoomsxBath, KitchenQual, TotalBath] 0.6653 0.7153 0.5735 0.6371
# 334       [GrLivArea, RoomsxBath, GarageCars] 0.6625 0.6741 0.6340 0.6555
# 335     [ExterQual, KitchenQual, TotalBsmtSF] 0.6859 0.6946 0.5944 0.6080
# 336        [ExterQual, TotalBsmtSF, 1stFlrSF] 0.7104 0.6731 0.5920 0.6137
# 337       [GrLivArea, GarageCars, GarageArea] 0.6487 0.6727 0.6426 0.6534
# 338       [BsmtQual, KitchenQual, GarageCars] 0.6491 0.6732 0.5956 0.6286
# 339         [BsmtQual, ExterQual, GarageArea] 0.6676 0.6656 0.6024 0.6272
# 340         [BsmtQual, TotalBath, GarageCars] 0.6637 0.6203 0.6394 0.6244
# 341      [RoomsxBath, TotalBsmtSF, TotalBath] 0.6941 0.6647 0.6417 0.5984
# 342         [BsmtQual, RoomsxBath, TotalBath] 0.6628 0.6660 0.6146 0.6034
# 343         [BsmtQual, ExterQual, GarageCars] 0.6619 0.6651 0.6005 0.6116
# 344         [BsmtQual, TotalBsmtSF, 1stFlrSF] 0.6704 0.6472 0.6285 0.5865
# 345    [Neighborhood, GarageCars, GarageArea] 0.6039 0.6465 0.6439 0.6441
# 346      [KitchenQual, TotalBsmtSF, 1stFlrSF] 0.6698 0.6686 0.5700 0.6210
# 347      [ExterQual, KitchenQual, GarageCars] 0.6535 0.6748 0.5650 0.6030
# 348      [ExterQual, KitchenQual, GarageArea] 0.6602 0.6617 0.5579 0.6193
# 349         [RoomsxBath, TotalBath, 1stFlrSF] 0.6633 0.6535 0.6086 0.6209
# 350        [TotalBsmtSF, TotalBath, 1stFlrSF] 0.6731 0.6269 0.6351 0.5871
# 351        [GrLivArea, RoomsxBath, TotalBath] 0.6190 0.6467 0.6041 0.6362
# 352      [RoomsxBath, GarageCars, GarageArea] 0.6237 0.6079 0.5690 0.6067
# 353       [RoomsxBath, TotalBath, GarageArea] 0.6220 0.6013 0.5646 0.6099
# 354     [KitchenQual, GarageCars, GarageArea] 0.6079 0.6368 0.5320 0.5847
# 355        [BsmtQual, ExterQual, KitchenQual] 0.5983 0.6564 0.5288 0.5500
# 356       [ExterQual, GarageCars, GarageArea] 0.6338 0.6272 0.5324 0.5720
# 357       [TotalBsmtSF, GarageCars, 1stFlrSF] 0.6445 0.5848 0.5994 0.5688
# 358       [RoomsxBath, TotalBath, GarageCars] 0.6133 0.5926 0.5568 0.5783
# 359        [BsmtQual, GarageCars, GarageArea] 0.5841 0.5834 0.5873 0.5731
# 360     [TotalBsmtSF, GarageCars, GarageArea] 0.6192 0.5686 0.5914 0.5475
# 361       [TotalBsmtSF, 1stFlrSF, GarageArea] 0.6289 0.5570 0.5782 0.5656
# 362       [TotalBath, GarageCars, GarageArea] 0.5782 0.5561 0.5592 0.5595
# 363        [GarageCars, 1stFlrSF, GarageArea] 0.6084 0.5604 0.5604 0.5363
#
#      Fold5    Avg    Std
# 0   0.8201 0.8386 0.0139
# 1   0.8167 0.8385 0.0142
# 2   0.8089 0.8349 0.0211
# 3   0.8025 0.8340 0.0219
# 4   0.8168 0.8329 0.0163
# 5   0.8126 0.8319 0.0162
# 6   0.8022 0.8305 0.0295
# 7   0.7972 0.8301 0.0288
# 8   0.8162 0.8267 0.0165
# 9   0.7867 0.8257 0.0302
# 10  0.7823 0.8251 0.0299
# 11  0.8099 0.8251 0.0171
# 12  0.8049 0.8235 0.0206
# 13  0.7995 0.8224 0.0208
# 14  0.7878 0.8150 0.0247
# 15  0.7856 0.8144 0.0308
# 16  0.8131 0.8142 0.0137
# 17  0.7947 0.8137 0.0120
# 18  0.7806 0.8130 0.0251
# 19  0.7793 0.8128 0.0301
# 20  0.7906 0.8126 0.0128
# 21  0.7985 0.8119 0.0117
# 22  0.7957 0.8116 0.0115
# 23  0.7742 0.8110 0.0245
# 24  0.7939 0.8109 0.0121
# 25  0.7914 0.8106 0.0121
# 26  0.7698 0.8105 0.0246
# 27  0.7742 0.8096 0.0245
# 28  0.7956 0.8093 0.0119
# 29  0.7696 0.8091 0.0244
# 30  0.7904 0.8080 0.0129
# 31  0.7678 0.8071 0.0274
# 32  0.7631 0.8067 0.0274
# 33  0.7637 0.8050 0.0282
# 34  0.7584 0.8043 0.0286
# 35  0.7610 0.8027 0.0284
# 36  0.7597 0.8027 0.0285
# 37  0.7778 0.8025 0.0259
# 38  0.7751 0.8020 0.0270
# 39  0.7543 0.8018 0.0291
# 40  0.7543 0.8018 0.0291
# 41  0.7543 0.8018 0.0291
# 42  0.7856 0.8014 0.0141
# 43  0.7817 0.8014 0.0151
# 44  0.7849 0.8012 0.0143
# 45  0.7715 0.8009 0.0253
# 46  0.7778 0.8005 0.0185
# 47  0.7701 0.8004 0.0271
# 48  0.7628 0.8004 0.0248
# 49  0.7768 0.8002 0.0158
# 50  0.7789 0.7996 0.0155
# 51  0.7789 0.7996 0.0155
# 52  0.7789 0.7996 0.0155
# 53  0.7797 0.7996 0.0162
# 54  0.7744 0.7995 0.0205
# 55  0.7659 0.7995 0.0276
# 56  0.7700 0.7995 0.0300
# 57  0.7635 0.7987 0.0269
# 298 0.6865 0.6774 0.0311
# 299 0.6638 0.6765 0.0183
# 300 0.6474 0.6763 0.0212
# 301 0.6678 0.6756 0.0322
# 302 0.6732 0.6752 0.0324
# 303 0.6352 0.6747 0.0224
# 304 0.6627 0.6746 0.0303
# 305 0.6343 0.6744 0.0244
# 306 0.6551 0.6733 0.0253
# 307 0.6626 0.6708 0.0250
# 308 0.6905 0.6706 0.0321
# 309 0.6615 0.6705 0.0283
# 310 0.6510 0.6695 0.0287
# 311 0.6550 0.6687 0.0338
# 312 0.6406 0.6686 0.0167
# 313 0.6588 0.6679 0.0321
# 314 0.6656 0.6677 0.0305
# 315 0.6737 0.6654 0.0343
# 316 0.6584 0.6633 0.0411
# 317 0.6563 0.6615 0.0430
# 318 0.6509 0.6594 0.0190
# 319 0.6632 0.6585 0.0390
# 320 0.6409 0.6573 0.0180
# 321 0.6449 0.6572 0.0256
# 322 0.6403 0.6569 0.0236
# 323 0.6438 0.6568 0.0277
# 324 0.6095 0.6563 0.0327
# 325 0.6361 0.6560 0.0262
# 326 0.6701 0.6552 0.0310
# 327 0.6909 0.6545 0.0371
# 328 0.6040 0.6522 0.0279
# 329 0.6549 0.6518 0.0118
# 330 0.6559 0.6515 0.0415
# 331 0.5625 0.6509 0.0480
# 332 0.6656 0.6482 0.0253
# 333 0.6496 0.6482 0.0458
# 334 0.6143 0.6481 0.0213
# 335 0.6464 0.6459 0.0402
# 336 0.6351 0.6449 0.0423
# 337 0.6005 0.6436 0.0238
# 338 0.6646 0.6422 0.0278
# 339 0.6413 0.6408 0.0245
# 340 0.6543 0.6404 0.0167
# 341 0.6031 0.6404 0.0364
# 342 0.6345 0.6363 0.0251
# 343 0.6416 0.6361 0.0261
# 344 0.6207 0.6307 0.0280
# 345 0.6082 0.6293 0.0191
# 346 0.6117 0.6282 0.0376
# 347 0.6413 0.6275 0.0390
# 348 0.6331 0.6264 0.0379
# 349 0.5824 0.6257 0.0296
# 350 0.6028 0.6250 0.0295
# 351 0.5607 0.6133 0.0301
# 352 0.5834 0.5981 0.0194
# 353 0.5791 0.5954 0.0208
# 354 0.6098 0.5942 0.0352
# 355 0.6272 0.5921 0.0473
# 356 0.5936 0.5918 0.0373
# 357 0.5562 0.5907 0.0306
# 358 0.5869 0.5856 0.0184
# 359 0.5745 0.5805 0.0056
# 360 0.5275 0.5708 0.0322
# 361 0.5244 0.5708 0.0341
# 362 0.5672 0.5640 0.0080
# 363 0.5369 0.5605 0.0262

# %% [markdown]
# ## Sequential Feature Selection:

# %%
response = ames['SalePrice']
features = ames.drop(columns = ['PID', 'SalePrice'])

# %%
cat_cols = [col for col in features.columns if features[col].dtype == 'object']
cat_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
cat_features = features.select_dtypes(include=['object'])
cat_features = pd.get_dummies(data = cat_features, drop_first = True)
cat_features = cat_features.replace({False: 0, True: 1})
cat_features.shape
# Out:
# (2580, 231)

# %%
num_features = features.select_dtypes(include=['int64', 'float64'])
num_features.shape
# Out:
# (2580, 44)

# %%
features_dum_drop = pd.concat([cat_features, num_features],axis = 1)
features_dum_drop.shape
# Out:
# (2580, 275)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, response, test_size=0.2, random_state=0)
X_train_drop, X_test_drop, y_train_drop, y_test_drop = train_test_split(features_dum_drop, response, test_size = .2, random_state=0)

# %%
features_dum_drop_noqual = features_dum_drop.drop(columns = ['OverallQual'])

# %%
X_train_drop_noqual, X_test_drop_noqual, y_train_drop_noqual, y_test_drop_noqual = train_test_split(features_dum_drop_noqual, response, test_size = .2, random_state=0)

# %%
selector = SequentialFeatureSelector(LinearRegression(),
                                         n_features_to_select= 20,
                                         direction='forward',
                                         scoring= 'r2',
                                         cv=5
                                        )
selector.fit(X_train_drop_noqual, y_train_drop_noqual)
feature_names = X_train_drop_noqual.columns
feature_names[selector.get_support()]
# Out:
# KeyboardInterrupt

# %%
def mlr_sfs(num, xtrain, xtest, ytrain, ytest):    
    test_score = []
    train_score = []
    feature_names_list = []

    for i in range(num):
        selector = SequentialFeatureSelector(LinearRegression(),
                                             n_features_to_select= i + 1,
                                             direction='forward',
                                             scoring= 'r2',
                                             cv=5
                                            )
        selector.fit(xtrain.astype(float), ytrain.astype(float))
        feature_names = xtrain.columns
        feature_names_list.append([feature_names[selector.get_support()]])
        lm = LinearRegression()
        lm.fit(X = xtrain.loc[:,feature_names[selector.get_support()]], y = ytrain)
        train_score.append(lm.score(xtrain.loc[:,feature_names[selector.get_support()]], ytrain))
        test_score.append(lm.score(xtest.loc[:,feature_names[selector.get_support()]], ytest))

    selector_df = pd.DataFrame(data = {'train_score': train_score, 'test_score': test_score, 'features_list': feature_names_list}).reset_index().rename(columns = {'index': 'number_of_features'})
    selector_df['number_of_features'] = selector_df['number_of_features'] + 1
    selector_df = selector_df.melt(id_vars = ['number_of_features','features_list'], value_vars = ['train_score', 'test_score'], var_name = 'score_type', value_name = 'score')

    return selector_df

# %%
my_sfs_qual = mlr_sfs(15, X_train_drop, X_test_drop, y_train_drop, y_test_drop)

# %%
qual_topfeatures_15 = []
for x in range(15):
    qual_topfeatures_15.append(my_sfs_qual.iloc[x, 1][0].tolist())

# %%
for x in range(15):    
    print(my_sfs_qual.iloc[x, 1])

# %%
my_sfs_noqual = mlr_sfs(15, X_train_drop_noqual, X_test_drop_noqual, y_train_drop_noqual, y_test_drop_noqual)

# %%
my_sfs_noqual

# %%
noqual_topfeatures_15 = []
for x in range(15):
    noqual_topfeatures_15.append(my_sfs_noqual.iloc[x, 1][0].tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 noqual_topfeatures_15 = []
#       2 for x in range(15):
# ----> 3     noqual_topfeatures_15.append(my_sfs_noqual.iloc[x, 1][0].tolist())
#
# NameError: name 'my_sfs_noqual' is not defined

# %%
sns.scatterplot(data = my_sfs_noqual, y = 'score', x = 'number_of_features', hue = 'score_type')
plt.title("Number of Features vs. Linear Regressions' R2")
plt.xlabel('Number of Features')
plt.ylabel('R2')
#Test score is higher than train while adding more features??

# %% [markdown]
# ### Report OLS results

# %%
def ols_results(X, y, features_list):
    for subset in features_list:
        print(subset)
        x = sm.add_constant(X[subset].reset_index(drop=True))
        y = y.reset_index(drop=True)
        model = sm.OLS(y, x.loc[:,x.columns.values].astype(float))
        results = model.fit()
        print(results.summary())
        print('-'*50, '\n\n\n')

# %%
ols_results(X_train_drop, y_train_drop, noqual_topfeatures_15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 ols_results(X_train_drop, y_train_drop, noqual_topfeatures_15)
#
# NameError: name 'noqual_topfeatures_15' is not defined

# %% [markdown]
# ## Plot Residuals

# %%
def mlr_residuals_plot(featurelist, x, y):
    X = x[featurelist]
    y = y
    
    lr = LinearRegression()
    y_pred = cross_val_predict(lr, X, y, cv = 5)
    
    fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
    PredictionErrorDisplay.from_predictions(
        y,
        y_pred=y_pred,
        kind="actual_vs_predicted",
        subsample=200,
        ax=axs[0],
        random_state=0,
    )
    axs[0].set_title(f"Actual vs. Predicted Values: {len(featurelist)} features")
    PredictionErrorDisplay.from_predictions(
        y,
        y_pred=y_pred,
        kind="residual_vs_predicted",
        subsample=200,
        ax=axs[1],
        random_state=0,
    )
    axs[1].set_title(f"Residuals vs. Predicted Values: {len(featurelist)} features")
    fig.suptitle("Plotting cross-validated predictions")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Repeat with Encoding:
# Predictions are consistently getting worse as price/square footage grows. I want to do some encoding to see if I can make this MLR model even more explainable/straightforward. Right now there's some cherry-picking of levels of conditions that are ordinal to some extent.

# %%
response_1 = ames['SalePrice']
features_1 = ames.drop(columns = ['PID', 'SalePrice'])

# %%
num_features = features_1.select_dtypes(include=['int64', 'float64'])

# %%
cat_cols_1 = [col for col in features_1.columns if features_1[col].dtype == 'object']
#cat_cols_1

# %% [markdown]
# ### Looking for candidates for ordinal encoding:
# LotShape: ['IR3', 'IR2', 'IR1', 'Reg']
# LandSlope: ['Sev', 'Mod', 'Gtl']
# ExterQual: ['Po', 'Fa', 'TA', 'Gd', 'Ex']
# ExterCond: ['Po', 'Fa', 'TA', 'Gd', 'Ex']
# BsmtQual: ['No Bsmt', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
# BsmtCond: ['No Bsmt', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
# BsmtExposure: ['No Bsmt', 'No', 'Mn', 'Av', 'Gd']
# BsmtFinType1: ['No Bsmt', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ']
# BsmtFinType2:['No Bsmt', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ']
# HeatingQC: ['Po', 'Fa', 'TA', 'Gd', 'Ex']
# Electrical: ['FuseP', 'FuseF', 'FuseA', 'SBrkr']
# KitchenQual: ['Po', 'Fa', 'TA', 'Gd', 'Ex']
# FireplaceQu: ['No Fireplace', 'Po', 'Fa', 'TA', 'Gd', 'Ex']
# GarageFinish: ['No Garage', 'Unf', 'RFn', 'Fin']
# GarageQual: ['No Garage','Po', 'Fa', 'TA', 'Gd', 'Ex']
# GarageCond: ['No Garage','Po', 'Fa', 'TA', 'Gd', 'Ex']
# PavedDrive: ['N', 'P', 'Y']
# PoolQC: ['No Pool','Fa', 'TA', 'Gd', 'Ex']
# Fence: ['No Fence','MnWw', 'GdWo', 'MnPrv', 'GdPrv']

# %%
#Hybrid of dummies and ordinal encoding in aims of getting some more explainability into the model
encoded_features_df = pd.DataFrame()
ordinal_cat = ['LotShape', 'LandSlope', 'ExterQual', 'ExterCond', 'HeatingQC', 'KitchenQual',\
               'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',\
               'Electrical', 'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond',\
               'PavedDrive', 'PoolQC', 'Fence']
for col in cat_cols_1:
    if col in ordinal_cat:
        if col == 'LotShape':
            enc = OrdinalEncoder(categories=[['IR3', 'IR2', 'IR1', 'Reg']])
        elif col == 'LandSlope':
            enc = OrdinalEncoder(categories=[['Sev', 'Mod', 'Gtl']])        
        elif col in ['ExterQual', 'ExterCond', 'HeatingQC', 'KitchenQual']:
            enc = OrdinalEncoder(categories=[['Po', 'Fa', 'TA', 'Gd', 'Ex']])    
        elif col in ['BsmtQual', 'BsmtCond']:
            enc = OrdinalEncoder(categories=[['No Bsmt', 'Po', 'Fa', 'TA', 'Gd', 'Ex']])        
        elif col == 'BsmtExposure':
            enc = OrdinalEncoder(categories=[['No Bsmt', 'No', 'Mn', 'Av', 'Gd']])
        elif col in ['BsmtFinType1', 'BsmtFinType2']:
            enc = OrdinalEncoder(categories=[['No Bsmt', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ']])    
        elif col == 'Electrical':
            enc = OrdinalEncoder(categories=[['FuseP', 'FuseF', 'FuseA', 'SBrkr']])    
        elif col == 'FireplaceQu':
            enc = OrdinalEncoder(categories=[['No Fireplace', 'Po', 'Fa', 'TA', 'Gd', 'Ex']])
        elif col == 'GarageFinish':
            enc = OrdinalEncoder(categories=[['No Garage', 'Unf', 'RFn', 'Fin']])
        elif col in ['GarageQual', 'GarageCond']:
            enc = OrdinalEncoder(categories=[['No Garage','Po', 'Fa', 'TA', 'Gd', 'Ex']])
        elif col == 'PavedDrive':
            enc = OrdinalEncoder(categories = [['N', 'P', 'Y']])
        elif col == 'PoolQC':
            enc = OrdinalEncoder(categories = [['No Pool','Fa', 'TA', 'Gd', 'Ex']])
        elif col == 'Fence':
            enc = OrdinalEncoder(categories = [['No Fence','MnWw', 'GdWo', 'MnPrv', 'GdPrv']])
        
        transformed_values = enc.fit_transform(features_1[[col]])
        encoded_features_df[col] = transformed_values.flatten()   
    else:
        encoded_cols = pd.get_dummies(data= features_1[col], drop_first = True)
        encoded_features_df = pd.concat([encoded_features_df, encoded_cols], axis=1)

encoded_features_df = encoded_features_df.replace({True: 1, False: 0})
encoded_features_df.reset_index(drop=True, inplace=True)
num_features.reset_index(drop=True, inplace = True)

features_1_encoded = pd.concat([encoded_features_df, num_features], axis = 1)

features_1_encoded.head(10)

# %%
X_train_enc, X_test_enc, y_train_enc, y_test_enc = train_test_split(features_1_encoded, response_1, test_size=0.2, random_state=0)
